# %% [markdown]
# # Objective of Notebook is to Identify which is the "Best" Stock to Buy When Stock Crashes.
# ### Eg. MCD that dropped from 217 to 148, a whopping = 31%

# %%
import os

# %%
mainpath  = './ticker_data/ticker_data_Daily_2021-12-11/'
for i in os.listdir(mainpath):
    print(i)
    print(os.path.getsize(mainpath + i))
    if os.path.getsize(mainpath + i) == 43:
        print('ITS 1!')
        os.remove(mainpath+i)
        print('REMOVED!')
# Out:
# AACG_ended_2021-12-11.csv
# 367155
# AACQU_ended_2021-12-11.csv
# 43
# ITS 1!
# REMOVED!
# AACQW_ended_2021-12-11.csv
# 43
# ITS 1!
# REMOVED!
# AACQ_ended_2021-12-11.csv
# 43
# ITS 1!
# REMOVED!
# AAC_ended_2021-12-11.csv
# 18611
# AAIC^B_ended_2021-12-11.csv
# 43
# ITS 1!
# REMOVED!
# AAIC^C_ended_2021-12-11.csv
# 43
# ITS 1!
# REMOVED!
# AAIC_ended_2021-12-11.csv
# 548291
# AAL_ended_2021-12-11.csv
# 611075
# AAMC_ended_2021-12-11.csv
# 200908
# AAME_ended_2021-12-11.csv
# 538756
# AAN_ended_2021-12-11.csv
# 28448
# AAOI_ended_2021-12-11.csv
# 221087
# AAON_ended_2021-12-11.csv
# 598874
# AAPL_ended_2021-12-11.csv
# 617261
# AAP_ended_2021-12-11.csv
# 545908
# AAQC_ended_2021-12-11.csv
# 15484
# AAT_ended_2021-12-11.csv
# 298325
# AAU_ended_2021-12-11.csv
# 464643
# AAWW_ended_2021-12-11.csv
# 438056
# AA_ended_2021-12-11.csv
# 145394
# ABBV_ended_2021-12-11.csv
# 244109
# ABB_ended_2021-12-11.csv
# 569242
# ABCB_ended_2021-12-11.csv
# 595201
# ABCL_ended_2021-12-11.csv
# 26643
# ...
