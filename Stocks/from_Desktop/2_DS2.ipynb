# %%
import pandas as pd

df = pd.read_csv('C:/Users/malco/Desktop/stocks_at_ATL.csv')

# %%
#Want only companies that have existed since 1999
df1 = df[df['start_date']==1999]#want companies 

df2 = df1[df1['perc_from_ATH_'] > 1.5]
df2
# Out:
#     Unnamed: 0  start_date  perc_from_ATH_ stock  current_price  minall  \
# 7           33        1999        3.058823  ABMC       0.130000    0.04
# 9           56        1999        2.803030  ACFN       0.370000    0.07
# 25         172        1999        1.824578   AIG      37.860001    6.60
# 33         222        1999        3.606557  ALJJ       1.100000    0.02
# 36         285        1999        1.695562  AMRN       4.890000    0.46
# 38         289        1999        3.117471  AMSC      23.420000    2.89
# 42         320        1999        2.954586  ANIX       3.070000    0.60
#
#          maxall  each_markup   markup_10   markup_20   markup_30   markup_40  \
# 7      4.250000     0.421000    0.461000    0.882000    1.303000    1.724000
# 9     13.200000     1.313000    1.383000    2.696000    4.009000    5.322000
# 25  2075.000000   206.840000  213.440000  420.280000  627.120000  833.960000
# 33    30.500000     3.048000    3.068000    6.116000    9.164000   12.212000
# ...
