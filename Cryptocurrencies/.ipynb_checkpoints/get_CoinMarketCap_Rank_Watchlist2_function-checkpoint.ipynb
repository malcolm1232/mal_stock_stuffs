# %% [markdown]
# # Get Cryptocurrency Number Watchlist from CoinMarketCap

# %%
import bs4 as bs
import requests

# %%
url = 'https://coinmarketcap.com/?page={}'
# resp = requests.get(url)
# soup = bs.BeautifulSoup(resp.text, 'lxml')

# %%
# get /currencies/btc 
count = 0
cryp_list = []

# %%
for page_num in range(1, 50+1):#shorten
    count = 0
    print('page_num:', page_num)
    url = 'https://coinmarketcap.com/?page={}'.format(page_num)
    resp = requests.get(url)
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    print(url)
    for i in soup.findAll('a', class_ = "cmc-link"):
        href_primary = i.get('href')
        href_sec = href_primary.split('/')[1]
        if href_sec == "currencies":
    #         print('count: {} , {}' .format(count,href_primary))
            if len(href_primary.split('/')) == 4:
                print('page: {} count: {} , {}' .format(page_num, count,href_primary))
                cryptocurrency_ticker = href_primary.split('/')[2]
                if cryptocurrency_ticker not in cryp_list:
                    cryp_list.append(cryptocurrency_ticker) 
                    print('appending: ',cryptocurrency_ticker)
        count+=1
    print('\n_____NEXT PAGE_____')
# Out:
# page_num: 1
# https://coinmarketcap.com/?page=1
# page: 1 count: 66 , /currencies/bitcoin/
# appending:  bitcoin
# page: 1 count: 69 , /currencies/bitcoin/?period=7d
# page: 1 count: 70 , /currencies/ethereum/
# appending:  ethereum
# page: 1 count: 73 , /currencies/ethereum/?period=7d
# page: 1 count: 74 , /currencies/binance-coin/
# appending:  binance-coin
# page: 1 count: 77 , /currencies/binance-coin/?period=7d
# page: 1 count: 78 , /currencies/tether/
# appending:  tether
# page: 1 count: 81 , /currencies/tether/?period=7d
# page: 1 count: 82 , /currencies/solana/
# appending:  solana
# page: 1 count: 85 , /currencies/solana/?period=7d
# page: 1 count: 86 , /currencies/cardano/
# appending:  cardano
# page: 1 count: 89 , /currencies/cardano/?period=7d
# page: 1 count: 90 , /currencies/xrp/
# appending:  xrp
# page: 1 count: 93 , /currencies/xrp/?period=7d
# page: 1 count: 94 , /currencies/usd-coin/
# appending:  usd-coin
# page: 1 count: 97 , /currencies/usd-coin/?period=7d
# page: 1 count: 98 , /currencies/polkadot-new/
# appending:  polkadot-new
# page: 1 count: 101 , /currencies/polkadot-new/?period=7d
# page: 1 count: 102 , /currencies/dogecoin/
# appending:  dogecoin
# page: 1 count: 105 , /currencies/dogecoin/?period=7d
# page: 1 count: 106 , /currencies/avalanche/
# appending:  avalanche
# page: 1 count: 107 , /currencies/shiba-inu/
# appending:  shiba-inu
# page: 1 count: 108 , /currencies/terra-luna/
# appending:  terra-luna
# page: 1 count: 109 , /currencies/crypto-com-coin/
# appending:  crypto-com-coin
# page: 1 count: 110 , /currencies/litecoin/
# appending:  litecoin
# page: 1 count: 111 , /currencies/polygon/
# appending:  polygon
# page: 1 count: 112 , /currencies/wrapped-bitcoin/
# appending:  wrapped-bitcoin
# page: 1 count: 113 , /currencies/uniswap/
# appending:  uniswap
# page: 1 count: 114 , /currencies/binance-usd/
# appending:  binance-usd
# page: 1 count: 115 , /currencies/chainlink/
# appending:  chainlink
# page: 1 count: 116 , /currencies/algorand/
# appending:  algorand
# page: 1 count: 117 , /currencies/bitcoin-cash/
# appending:  bitcoin-cash
# page: 1 count: 118 , /currencies/axie-infinity/
# appending:  axie-infinity
# page: 1 count: 119 , /currencies/decentraland/
# appending:  decentraland
# page: 1 count: 120 , /currencies/stellar/
# appending:  stellar
# page: 1 count: 121 , /currencies/vechain/
# appending:  vechain
# page: 1 count: 122 , /currencies/internet-computer/
# appending:  internet-computer
# page: 1 count: 123 , /currencies/elrond-egld/
# appending:  elrond-egld
# page: 1 count: 124 , /currencies/terrausd/
# appending:  terrausd
# page: 1 count: 125 , /currencies/filecoin/
# appending:  filecoin
# page: 1 count: 126 , /currencies/ftx-token/
# appending:  ftx-token
# page: 1 count: 127 , /currencies/tron/
# appending:  tron
# page: 1 count: 128 , /currencies/theta/
# appending:  theta
# page: 1 count: 129 , /currencies/multi-collateral-dai/
# appending:  multi-collateral-dai
# page: 1 count: 130 , /currencies/ethereum-classic/
# appending:  ethereum-classic
# page: 1 count: 131 , /currencies/hedera/
# appending:  hedera
# page: 1 count: 132 , /currencies/cosmos/
# appending:  cosmos
# page: 1 count: 133 , /currencies/bitcoin-bep2/
# appending:  bitcoin-bep2
# page: 1 count: 134 , /currencies/the-sandbox/
# appending:  the-sandbox
# page: 1 count: 135 , /currencies/fantom/
# appending:  fantom
# page: 1 count: 136 , /currencies/near-protocol/
# appending:  near-protocol
# page: 1 count: 137 , /currencies/tezos/
# appending:  tezos
# page: 1 count: 138 , /currencies/the-graph/
# appending:  the-graph
# page: 1 count: 139 , /currencies/gala/
# appending:  gala
# page: 1 count: 140 , /currencies/monero/
# appending:  monero
# page: 1 count: 141 , /currencies/helium/
# appending:  helium
# page: 1 count: 142 , /currencies/klaytn/
# appending:  klaytn
# page: 1 count: 143 , /currencies/eos/
# appending:  eos
# page: 1 count: 144 , /currencies/flow/
# appending:  flow
# page: 1 count: 145 , /currencies/iota/
# appending:  iota
# page: 1 count: 146 , /currencies/loopring/
# appending:  loopring
# page: 1 count: 147 , /currencies/stacks/
# appending:  stacks
# page: 1 count: 148 , /currencies/aave/
# appending:  aave
# page: 1 count: 149 , /currencies/pancakeswap/
# appending:  pancakeswap
# page: 1 count: 150 , /currencies/kusama/
# appending:  kusama
# page: 1 count: 151 , /currencies/unus-sed-leo/
# appending:  unus-sed-leo
# page: 1 count: 152 , /currencies/bittorrent/
# appending:  bittorrent
# page: 1 count: 153 , /currencies/zcash/
# appending:  zcash
# page: 1 count: 154 , /currencies/maker/
# appending:  maker
# page: 1 count: 155 , /currencies/enjin-coin/
# appending:  enjin-coin
# page: 1 count: 156 , /currencies/harmony/
# appending:  harmony
# page: 1 count: 157 , /currencies/thorchain/
# appending:  thorchain
# page: 1 count: 158 , /currencies/bitcoin-sv/
# appending:  bitcoin-sv
# page: 1 count: 159 , /currencies/ecash/
# appending:  ecash
# page: 1 count: 160 , /currencies/kadena/
# appending:  kadena
# page: 1 count: 161 , /currencies/neo/
# appending:  neo
# page: 1 count: 162 , /currencies/chiliz/
# appending:  chiliz
# page: 1 count: 163 , /currencies/amp/
# appending:  amp
# page: 1 count: 164 , /currencies/quant/
# appending:  quant
# page: 1 count: 165 , /currencies/waves/
# appending:  waves
# page: 1 count: 166 , /currencies/curve-dao-token/
# appending:  curve-dao-token
# page: 1 count: 167 , /currencies/kucoin-token/
# appending:  kucoin-token
# page: 1 count: 168 , /currencies/basic-attention-token/
# appending:  basic-attention-token
# page: 1 count: 169 , /currencies/holo/
# appending:  holo
# page: 1 count: 170 , /currencies/arweave/
# appending:  arweave
# page: 1 count: 171 , /currencies/dash/
# appending:  dash
# page: 1 count: 172 , /currencies/celo/
# appending:  celo
# page: 1 count: 173 , /currencies/compound/
# appending:  compound
# page: 1 count: 174 , /currencies/theta-fuel/
# appending:  theta-fuel
# page: 1 count: 175 , /currencies/nexo/
# appending:  nexo
# page: 1 count: 176 , /currencies/qtum/
# appending:  qtum
# page: 1 count: 177 , /currencies/nem/
# appending:  nem
# page: 1 count: 178 , /currencies/okb/
# appending:  okb
# page: 1 count: 179 , /currencies/huobi-token/
# appending:  huobi-token
# page: 1 count: 180 , /currencies/iotex/
# appending:  iotex
# page: 1 count: 181 , /currencies/decred/
# appending:  decred
# page: 1 count: 182 , /currencies/mina/
# appending:  mina
# page: 1 count: 183 , /currencies/immutable-x/
# appending:  immutable-x
# page: 1 count: 184 , /currencies/voyager-token/
# appending:  voyager-token
# page: 1 count: 185 , /currencies/horizen/
# appending:  horizen
# page: 1 count: 186 , /currencies/trueusd/
# appending:  trueusd
# page: 1 count: 187 , /currencies/audius/
# appending:  audius
# page: 1 count: 188 , /currencies/ankr/
# appending:  ankr
# page: 1 count: 189 , /currencies/wax/
# appending:  wax
# page: 1 count: 190 , /currencies/icon/
# appending:  icon
# page: 1 count: 191 , /currencies/omg/
# appending:  omg
# page: 1 count: 192 , /currencies/siacoin/
# appending:  siacoin
# page: 1 count: 193 , /currencies/livepeer/
# appending:  livepeer
# page: 1 count: 194 , /currencies/ravencoin/
# appending:  ravencoin
# page: 1 count: 195 , /currencies/oasis-network/
# appending:  oasis-network
#
# _____NEXT PAGE_____
# page_num: 2
# https://coinmarketcap.com/?page=2
# page: 2 count: 66 , /currencies/xinfin/
# appending:  xinfin
# page: 2 count: 69 , /currencies/xinfin/?period=7d
# page: 2 count: 70 , /currencies/yearn-finance/
# appending:  yearn-finance
# page: 2 count: 73 , /currencies/yearn-finance/?period=7d
# page: 2 count: 74 , /currencies/zilliqa/
# appending:  zilliqa
# page: 2 count: 77 , /currencies/zilliqa/?period=7d
# page: 2 count: 78 , /currencies/bora/
# appending:  bora
# page: 2 count: 81 , /currencies/bora/?period=7d
# page: 2 count: 82 , /currencies/sushiswap/
# appending:  sushiswap
# page: 2 count: 85 , /currencies/sushiswap/?period=7d
# page: 2 count: 86 , /currencies/0x/
# appending:  0x
# page: 2 count: 89 , /currencies/0x/?period=7d
# page: 2 count: 90 , /currencies/bitcoin-gold/
# appending:  bitcoin-gold
# page: 2 count: 93 , /currencies/bitcoin-gold/?period=7d
# page: 2 count: 94 , /currencies/renbtc/
# appending:  renbtc
# page: 2 count: 97 , /currencies/renbtc/?period=7d
# page: 2 count: 98 , /currencies/bancor/
# appending:  bancor
# page: 2 count: 101 , /currencies/bancor/?period=7d
# page: 2 count: 102 , /currencies/revain/
# appending:  revain
# page: 2 count: 105 , /currencies/revain/?period=7d
# page: 2 count: 106 , /currencies/ren/
# appending:  ren
# page: 2 count: 107 , /currencies/celsius/
# appending:  celsius
# page: 2 count: 108 , /currencies/paxos-standard/
# appending:  paxos-standard
# page: 2 count: 109 , /currencies/hive-blockchain/
# appending:  hive-blockchain
# page: 2 count: 110 , /currencies/secret/
# appending:  secret
# page: 2 count: 111 , /currencies/dogelon/
# appending:  dogelon
# page: 2 count: 112 , /currencies/storj/
# appending:  storj
# page: 2 count: 113 , /currencies/nervos-network/
# appending:  nervos-network
# page: 2 count: 114 , /currencies/synthetix-network-token/
# appending:  synthetix-network-token
# page: 2 count: 115 , /currencies/perpetual-protocol/
# appending:  perpetual-protocol
# page: 2 count: 116 , /currencies/velas/
# appending:  velas
# page: 2 count: 117 , /currencies/raydium/
# appending:  raydium
# page: 2 count: 118 , /currencies/ontology/
# appending:  ontology
# page: 2 count: 119 , /currencies/uma/
# appending:  uma
# page: 2 count: 120 , /currencies/skale-network/
# appending:  skale-network
# page: 2 count: 121 , /currencies/telcoin/
# appending:  telcoin
# page: 2 count: 122 , /currencies/serum/
# appending:  serum
# page: 2 count: 123 , /currencies/ocean-protocol/
# appending:  ocean-protocol
# page: 2 count: 124 , /currencies/golem-network-tokens/
# appending:  golem-network-tokens
# page: 2 count: 125 , /currencies/dydx/
# appending:  dydx
# page: 2 count: 126 , /currencies/request/
# appending:  request
# page: 2 count: 127 , /currencies/iostoken/
# appending:  iostoken
# page: 2 count: 128 , /currencies/ceek-vr/
# appending:  ceek-vr
# page: 2 count: 129 , /currencies/digibyte/
# appending:  digibyte
# page: 2 count: 130 , /currencies/kava/
# appending:  kava
# page: 2 count: 131 , /currencies/moonriver/
# appending:  moonriver
# page: 2 count: 132 , /currencies/swissborg/
# appending:  swissborg
# page: 2 count: 133 , /currencies/1inch/
# appending:  1inch
# page: 2 count: 134 , /currencies/polymath-network/
# appending:  polymath-network
# page: 2 count: 135 , /currencies/gnosis-gno/
# appending:  gnosis-gno
# page: 2 count: 136 , /currencies/celer-network/
# appending:  celer-network
# page: 2 count: 137 , /currencies/wink/
# appending:  wink
# page: 2 count: 138 , /currencies/xyo/
# appending:  xyo
# page: 2 count: 139 , /currencies/myneighboralice/
# appending:  myneighboralice
# page: 2 count: 140 , /currencies/nucypher/
# appending:  nucypher
# page: 2 count: 141 , /currencies/reserve-rights/
# appending:  reserve-rights
# page: 2 count: 142 , /currencies/wootrade/
# appending:  wootrade
# page: 2 count: 143 , /currencies/origintrail/
# appending:  origintrail
# page: 2 count: 144 , /currencies/digitalbits/
# appending:  digitalbits
# page: 2 count: 145 , /currencies/fetch/
# appending:  fetch
# page: 2 count: 146 , /currencies/injective-protocol/
# appending:  injective-protocol
# page: 2 count: 147 , /currencies/casper/
# appending:  casper
# page: 2 count: 148 , /currencies/gatetoken/
# appending:  gatetoken
# page: 2 count: 149 , /currencies/just/
# appending:  just
# page: 2 count: 150 , /currencies/neutrino-usd/
# appending:  neutrino-usd
# page: 2 count: 151 , /currencies/chromia/
# appending:  chromia
# page: 2 count: 152 , /currencies/ultra/
# appending:  ultra
# page: 2 count: 153 , /currencies/mdex/
# appending:  mdex
# page: 2 count: 154 , /currencies/syscoin/
# appending:  syscoin
# page: 2 count: 155 , /currencies/cartesi/
# appending:  cartesi
# page: 2 count: 156 , /currencies/dent/
# appending:  dent
# page: 2 count: 157 , /currencies/lisk/
# appending:  lisk
# page: 2 count: 158 , /currencies/function-x/
# appending:  function-x
# page: 2 count: 159 , /currencies/swipe/
# appending:  swipe
# page: 2 count: 160 , /currencies/dvision-network/
# appending:  dvision-network
# page: 2 count: 161 , /currencies/zel/
# appending:  zel
# page: 2 count: 162 , /currencies/medibloc/
# appending:  medibloc
# page: 2 count: 163 , /currencies/alpha-finance-lab/
# appending:  alpha-finance-lab
# page: 2 count: 164 , /currencies/fei-usd/
# appending:  fei-usd
# page: 2 count: 165 , /currencies/coti/
# appending:  coti
# page: 2 count: 166 , /currencies/reef/
# appending:  reef
# page: 2 count: 167 , /currencies/wazirx/
# appending:  wazirx
# page: 2 count: 168 , /currencies/origin-protocol/
# appending:  origin-protocol
# page: 2 count: 169 , /currencies/verge/
# appending:  verge
# page: 2 count: 170 , /currencies/btc-standard-hashrate-token/
# appending:  btc-standard-hashrate-token
# page: 2 count: 171 , /currencies/civic/
# appending:  civic
# page: 2 count: 172 , /currencies/phantasma/
# appending:  phantasma
# page: 2 count: 173 , /currencies/ardor/
# appending:  ardor
# page: 2 count: 174 , /currencies/vethor-token/
# appending:  vethor-token
# page: 2 count: 175 , /currencies/nkn/
# appending:  nkn
# page: 2 count: 176 , /currencies/status/
# appending:  status
# page: 2 count: 177 , /currencies/bakerytoken/
# appending:  bakerytoken
# page: 2 count: 178 , /currencies/orchid/
# appending:  orchid
# page: 2 count: 179 , /currencies/mx-token/
# appending:  mx-token
# page: 2 count: 180 , /currencies/polkastarter/
# appending:  polkastarter
# page: 2 count: 181 , /currencies/rlc/
# appending:  rlc
# page: 2 count: 182 , /currencies/bitcoin-diamond/
# appending:  bitcoin-diamond
# page: 2 count: 183 , /currencies/divi/
# appending:  divi
# page: 2 count: 184 , /currencies/conflux-network/
# appending:  conflux-network
# page: 2 count: 185 , /currencies/pax-gold/
# appending:  pax-gold
# page: 2 count: 186 , /currencies/energy-web-token/
# appending:  energy-web-token
# page: 2 count: 187 , /currencies/ampleforth/
# appending:  ampleforth
# page: 2 count: 188 , /currencies/badger-dao/
# appending:  badger-dao
# page: 2 count: 189 , /currencies/stormx/
# appending:  stormx
# page: 2 count: 190 , /currencies/ontology-gas/
# appending:  ontology-gas
# page: 2 count: 191 , /currencies/aelf/
# appending:  aelf
# page: 2 count: 192 , /currencies/crypto-com/
# appending:  crypto-com
# page: 2 count: 193 , /currencies/band-protocol/
# appending:  band-protocol
# page: 2 count: 194 , /currencies/power-ledger/
# appending:  power-ledger
# page: 2 count: 195 , /currencies/husd/
# appending:  husd
#
# _____NEXT PAGE_____
# page_num: 3
# https://coinmarketcap.com/?page=3
# page: 3 count: 66 , /currencies/hex/
# appending:  hex
# page: 3 count: 69 , /currencies/hex/?period=7d
# page: 3 count: 70 , /currencies/steth/
# appending:  steth
# page: 3 count: 73 , /currencies/steth/?period=7d
# page: 3 count: 74 , /currencies/wbnb/
# appending:  wbnb
# page: 3 count: 77 , /currencies/wbnb/?period=7d
# page: 3 count: 78 , /currencies/huobi-btc/
# appending:  huobi-btc
# page: 3 count: 81 , /currencies/huobi-btc/?period=7d
# page: 3 count: 82 , /currencies/symbol/
# appending:  symbol
# page: 3 count: 85 , /currencies/symbol/?period=7d
# page: 3 count: 86 , /currencies/wemix/
# appending:  wemix
# page: 3 count: 89 , /currencies/wemix/?period=7d
# page: 3 count: 90 , /currencies/youcash/
# appending:  youcash
# page: 3 count: 93 , /currencies/youcash/?period=7d
# page: 3 count: 94 , /currencies/link/
# appending:  link
# page: 3 count: 97 , /currencies/link/?period=7d
# page: 3 count: 98 , /currencies/safemoon/
# appending:  safemoon
# page: 3 count: 101 , /currencies/safemoon/?period=7d
# page: 3 count: 102 , /currencies/bitdao/
# appending:  bitdao
# page: 3 count: 105 , /currencies/bitdao/?period=7d
# page: 3 count: 106 , /currencies/creditcoin/
# appending:  creditcoin
# page: 3 count: 107 , /currencies/ethereum-name-service/
# appending:  ethereum-name-service
# page: 3 count: 108 , /currencies/frax/
# appending:  frax
# page: 3 count: 109 , /currencies/illuvium/
# appending:  illuvium
# page: 3 count: 110 , /currencies/venus-bnb/
# appending:  venus-bnb
# page: 3 count: 111 , /currencies/apenft/
# appending:  apenft
# page: 3 count: 112 , /currencies/rally/
# appending:  rally
# page: 3 count: 113 , /currencies/ecomi/
# appending:  ecomi
# page: 3 count: 114 , /currencies/mobilecoin/
# appending:  mobilecoin
# page: 3 count: 115 , /currencies/convex-finance/
# appending:  convex-finance
# page: 3 count: 116 , /currencies/nxm/
# appending:  nxm
# page: 3 count: 117 , /currencies/defichain/
# appending:  defichain
# page: 3 count: 118 , /currencies/bloktopia/
# appending:  bloktopia
# page: 3 count: 119 , /currencies/the-transfer-token/
# appending:  the-transfer-token
# page: 3 count: 120 , /currencies/counos-x/
# appending:  counos-x
# page: 3 count: 121 , /currencies/radio-caca/
# appending:  radio-caca
# page: 3 count: 122 , /currencies/render-token/
# appending:  render-token
# page: 3 count: 123 , /currencies/sologenic/
# appending:  sologenic
# page: 3 count: 124 , /currencies/mobox/
# appending:  mobox
# page: 3 count: 125 , /currencies/vulcan-forged-pyr/
# appending:  vulcan-forged-pyr
# page: 3 count: 126 , /currencies/alitas/
# appending:  alitas
# page: 3 count: 127 , /currencies/superfarm/
# appending:  superfarm
# page: 3 count: 128 , /currencies/jasmy/
# appending:  jasmy
# page: 3 count: 129 , /currencies/yooshi/
# appending:  yooshi
# page: 3 count: 130 , /currencies/liquity-usd/
# appending:  liquity-usd
# page: 3 count: 131 , /currencies/whitecoin/
# appending:  whitecoin
# page: 3 count: 132 , /currencies/nano/
# appending:  nano
# page: 3 count: 133 , /currencies/anchor-protocol/
# appending:  anchor-protocol
# page: 3 count: 134 , /currencies/star-link/
# appending:  star-link
# page: 3 count: 135 , /currencies/coin98/
# appending:  coin98
# page: 3 count: 136 , /currencies/yield-guild-games/
# appending:  yield-guild-games
# page: 3 count: 137 , /currencies/playdapp/
# appending:  playdapp
# page: 3 count: 138 , /currencies/rocket-pool/
# appending:  rocket-pool
# page: 3 count: 139 , /currencies/tribe/
# appending:  tribe
# page: 3 count: 140 , /currencies/bifrost/
# appending:  bifrost
# page: 3 count: 141 , /currencies/orbit-chain/
# appending:  orbit-chain
# page: 3 count: 142 , /currencies/keep-network/
# appending:  keep-network
# page: 3 count: 143 , /currencies/platon/
# appending:  platon
# page: 3 count: 144 , /currencies/persistence/
# appending:  persistence
# page: 3 count: 145 , /currencies/mask-network/
# appending:  mask-network
# page: 3 count: 146 , /currencies/keystone-of-opportunity-knowledge/
# appending:  keystone-of-opportunity-knowledge
# page: 3 count: 147 , /currencies/merit-circle/
# appending:  merit-circle
# page: 3 count: 148 , /currencies/glitzkoin/
# appending:  glitzkoin
# page: 3 count: 149 , /currencies/wilder-world/
# appending:  wilder-world
# page: 3 count: 150 , /currencies/rmrk/
# appending:  rmrk
# page: 3 count: 151 , /currencies/braintrust/
# appending:  braintrust
# page: 3 count: 152 , /currencies/joe/
# appending:  joe
# page: 3 count: 153 , /currencies/star-atlas/
# appending:  star-atlas
# page: 3 count: 154 , /currencies/mines-of-dalarnia/
# appending:  mines-of-dalarnia
# page: 3 count: 155 , /currencies/deversifi/
# appending:  deversifi
# page: 3 count: 156 , /currencies/bonfida/
# appending:  bonfida
# page: 3 count: 157 , /currencies/hathor/
# appending:  hathor
# page: 3 count: 158 , /currencies/bitpanda-ecosystem-token/
# appending:  bitpanda-ecosystem-token
# page: 3 count: 159 , /currencies/wrapped-ncg/
# appending:  wrapped-ncg
# page: 3 count: 160 , /currencies/alien-worlds/
# appending:  alien-worlds
# page: 3 count: 161 , /currencies/trust-wallet-token/
# appending:  trust-wallet-token
# page: 3 count: 162 , /currencies/beta-finance/
# appending:  beta-finance
# page: 3 count: 163 , /currencies/pundix-new/
# appending:  pundix-new
# page: 3 count: 164 , /currencies/dao-maker/
# appending:  dao-maker
# page: 3 count: 165 , /currencies/kyber-network-crystal-v2/
# appending:  kyber-network-crystal-v2
# page: 3 count: 166 , /currencies/redfox-labs/
# appending:  redfox-labs
# page: 3 count: 167 , /currencies/seedify-fund/
# appending:  seedify-fund
# page: 3 count: 168 , /currencies/centrality/
# appending:  centrality
# page: 3 count: 169 , /currencies/kardiachain/
# appending:  kardiachain
# page: 3 count: 170 , /currencies/chia-network/
# appending:  chia-network
# page: 3 count: 171 , /currencies/sun-token/
# appending:  sun-token
# page: 3 count: 172 , /currencies/pirate-chain/
# appending:  pirate-chain
# page: 3 count: 173 , /currencies/alchemix/
# appending:  alchemix
# page: 3 count: 174 , /currencies/vectorspace-ai/
# appending:  vectorspace-ai
# page: 3 count: 175 , /currencies/alchemy-pay/
# appending:  alchemy-pay
# page: 3 count: 176 , /currencies/mango-markets/
# appending:  mango-markets
# page: 3 count: 177 , /currencies/rari-governance-token/
# appending:  rari-governance-token
# page: 3 count: 178 , /currencies/efinity/
# appending:  efinity
# page: 3 count: 179 , /currencies/radix/
# appending:  radix
# page: 3 count: 180 , /currencies/anyswap/
# appending:  anyswap
# page: 3 count: 181 , /currencies/frax-share/
# appending:  frax-share
# page: 3 count: 182 , /currencies/radicle/
# appending:  radicle
# page: 3 count: 183 , /currencies/humanscape/
# appending:  humanscape
# page: 3 count: 184 , /currencies/sovryn/
# appending:  sovryn
# page: 3 count: 185 , /currencies/lukso/
# appending:  lukso
# page: 3 count: 186 , /currencies/bitmax-token/
# appending:  bitmax-token
# page: 3 count: 187 , /currencies/telos/
# appending:  telos
# page: 3 count: 188 , /currencies/idex/
# appending:  idex
# page: 3 count: 189 , /currencies/binaryx/
# appending:  binaryx
# page: 3 count: 190 , /currencies/orbs/
# appending:  orbs
# page: 3 count: 191 , /currencies/safepal/
# appending:  safepal
# page: 3 count: 192 , /currencies/stratis/
# appending:  stratis
# page: 3 count: 193 , /currencies/sapphire/
# appending:  sapphire
# page: 3 count: 194 , /currencies/ark/
# appending:  ark
# page: 3 count: 195 , /currencies/steem/
# appending:  steem
#
# _____NEXT PAGE_____
# page_num: 4
# https://coinmarketcap.com/?page=4
# page: 4 count: 66 , /currencies/tomochain/
# appending:  tomochain
# page: 4 count: 69 , /currencies/tomochain/?period=7d
# page: 4 count: 70 , /currencies/unibright/
# appending:  unibright
# page: 4 count: 73 , /currencies/unibright/?period=7d
# page: 4 count: 74 , /currencies/prometeus/
# appending:  prometeus
# page: 4 count: 77 , /currencies/prometeus/?period=7d
# page: 4 count: 78 , /currencies/orion-protocol/
# appending:  orion-protocol
# page: 4 count: 81 , /currencies/orion-protocol/?period=7d
# page: 4 count: 82 , /currencies/venus/
# appending:  venus
# page: 4 count: 85 , /currencies/venus/?period=7d
# page: 4 count: 86 , /currencies/constellation/
# appending:  constellation
# page: 4 count: 89 , /currencies/constellation/?period=7d
# page: 4 count: 90 , /currencies/electroneum/
# appending:  electroneum
# page: 4 count: 93 , /currencies/electroneum/?period=7d
# page: 4 count: 94 , /currencies/verasity/
# appending:  verasity
# page: 4 count: 97 , /currencies/verasity/?period=7d
# page: 4 count: 98 , /currencies/terra-virtua-kolect/
# appending:  terra-virtua-kolect
# page: 4 count: 101 , /currencies/terra-virtua-kolect/?period=7d
# page: 4 count: 102 , /currencies/akash-network/
# appending:  akash-network
# page: 4 count: 105 , /currencies/akash-network/?period=7d
# page: 4 count: 106 , /currencies/augur/
# appending:  augur
# page: 4 count: 107 , /currencies/truefi-token/
# appending:  truefi-token
# page: 4 count: 108 , /currencies/insure/
# appending:  insure
# page: 4 count: 109 , /currencies/numeraire/
# appending:  numeraire
# page: 4 count: 110 , /currencies/maidsafecoin/
# appending:  maidsafecoin
# page: 4 count: 111 , /currencies/venus-btc/
# appending:  venus-btc
# page: 4 count: 112 , /currencies/qredo/
# appending:  qredo
# page: 4 count: 113 , /currencies/gitcoin/
# appending:  gitcoin
# page: 4 count: 114 , /currencies/dawn-protocol/
# appending:  dawn-protocol
# page: 4 count: 115 , /currencies/hedgetrade/
# appending:  hedgetrade
# page: 4 count: 116 , /currencies/singularitynet/
# appending:  singularitynet
# page: 4 count: 117 , /currencies/somesing/
# appending:  somesing
# page: 4 count: 118 , /currencies/mvl/
# appending:  mvl
# page: 4 count: 119 , /currencies/abbc-coin/
# appending:  abbc-coin
# page: 4 count: 120 , /currencies/lcx/
# appending:  lcx
# page: 4 count: 121 , /currencies/ellipsis/
# appending:  ellipsis
# page: 4 count: 122 , /currencies/aavegotchi/
# appending:  aavegotchi
# page: 4 count: 123 , /currencies/ergo/
# appending:  ergo
# page: 4 count: 124 , /currencies/funtoken/
# appending:  funtoken
# page: 4 count: 125 , /currencies/metadium/
# appending:  metadium
# page: 4 count: 126 , /currencies/linear/
# appending:  linear
# page: 4 count: 127 , /currencies/hxro/
# appending:  hxro
# page: 4 count: 128 , /currencies/keep3rv1/
# appending:  keep3rv1
# page: 4 count: 129 , /currencies/aragon/
# appending:  aragon
# page: 4 count: 130 , /currencies/gamefi/
# appending:  gamefi
# page: 4 count: 131 , /currencies/mirror-protocol/
# appending:  mirror-protocol
# page: 4 count: 132 , /currencies/star-atlas-polis/
# appending:  star-atlas-polis
# page: 4 count: 133 , /currencies/zenon/
# appending:  zenon
# page: 4 count: 134 , /currencies/derace/
# appending:  derace
# page: 4 count: 135 , /currencies/samoyedcoin/
# appending:  samoyedcoin
# page: 4 count: 136 , /currencies/c20/
# appending:  c20
# page: 4 count: 137 , /currencies/dero/
# appending:  dero
# page: 4 count: 138 , /currencies/aioz-network/
# appending:  aioz-network
# page: 4 count: 139 , /currencies/defi-land/
# appending:  defi-land
# page: 4 count: 140 , /currencies/gemini-dollar/
# appending:  gemini-dollar
# page: 4 count: 141 , /currencies/quarkchain/
# appending:  quarkchain
# page: 4 count: 142 , /currencies/derivadao/
# appending:  derivadao
# page: 4 count: 143 , /currencies/proton/
# appending:  proton
# page: 4 count: 144 , /currencies/syntropy/
# appending:  syntropy
# page: 4 count: 145 , /currencies/molecular-future/
# appending:  molecular-future
# page: 4 count: 146 , /currencies/standard-tokenization-protocol/
# appending:  standard-tokenization-protocol
# page: 4 count: 147 , /currencies/kin/
# appending:  kin
# page: 4 count: 148 , /currencies/decentral-games/
# appending:  decentral-games
# page: 4 count: 149 , /currencies/rsk-infrastructure-framework/
# appending:  rsk-infrastructure-framework
# page: 4 count: 150 , /currencies/metal/
# appending:  metal
# page: 4 count: 151 , /currencies/uquid-coin/
# appending:  uquid-coin
# page: 4 count: 152 , /currencies/handshake/
# appending:  handshake
# page: 4 count: 153 , /currencies/everscale/
# appending:  everscale
# page: 4 count: 154 , /currencies/centrifuge/
# appending:  centrifuge
# page: 4 count: 155 , /currencies/automata-network/
# appending:  automata-network
# page: 4 count: 156 , /currencies/titanswap/
# appending:  titanswap
# page: 4 count: 157 , /currencies/venus-eth/
# appending:  venus-eth
# page: 4 count: 158 , /currencies/defi-pulse-index/
# appending:  defi-pulse-index
# page: 4 count: 159 , /currencies/tether-gold/
# appending:  tether-gold
# page: 4 count: 160 , /currencies/enzyme/
# appending:  enzyme
# page: 4 count: 161 , /currencies/deapcoin/
# appending:  deapcoin
# page: 4 count: 162 , /currencies/solanium/
# appending:  solanium
# page: 4 count: 163 , /currencies/rakon/
# appending:  rakon
# page: 4 count: 164 , /currencies/everipedia/
# appending:  everipedia
# page: 4 count: 165 , /currencies/superrare/
# appending:  superrare
# page: 4 count: 166 , /currencies/sport-and-leisure/
# appending:  sport-and-leisure
# page: 4 count: 167 , /currencies/tokocrypto/
# appending:  tokocrypto
# page: 4 count: 168 , /currencies/bscpad/
# appending:  bscpad
# page: 4 count: 169 , /currencies/certik/
# appending:  certik
# page: 4 count: 170 , /currencies/trustswap/
# appending:  trustswap
# page: 4 count: 171 , /currencies/smooth-love-potion/
# appending:  smooth-love-potion
# page: 4 count: 172 , /currencies/metisdao/
# appending:  metisdao
# page: 4 count: 173 , /currencies/api3/
# appending:  api3
# page: 4 count: 174 , /currencies/adventure-gold/
# appending:  adventure-gold
# page: 4 count: 175 , /currencies/boson-protocol/
# appending:  boson-protocol
# page: 4 count: 176 , /currencies/bloomzed-token/
# appending:  bloomzed-token
# page: 4 count: 177 , /currencies/phala-network/
# appending:  phala-network
# page: 4 count: 178 , /currencies/utrust/
# appending:  utrust
# page: 4 count: 179 , /currencies/wanchain/
# appending:  wanchain
# page: 4 count: 180 , /currencies/arpa-chain/
# appending:  arpa-chain
# page: 4 count: 181 , /currencies/poa/
# appending:  poa
# page: 4 count: 182 , /currencies/ethernity-chain/
# appending:  ethernity-chain
# page: 4 count: 183 , /currencies/peakdefi/
# appending:  peakdefi
# page: 4 count: 184 , /currencies/morpheus-network/
# appending:  morpheus-network
# page: 4 count: 185 , /currencies/dkargo/
# appending:  dkargo
# page: 4 count: 186 , /currencies/litentry/
# appending:  litentry
# page: 4 count: 187 , /currencies/dodo/
# appending:  dodo
# page: 4 count: 188 , /currencies/allianceblock/
# appending:  allianceblock
# page: 4 count: 189 , /currencies/deeper-network/
# appending:  deeper-network
# page: 4 count: 190 , /currencies/babyswap/
# appending:  babyswap
# page: 4 count: 191 , /currencies/xsgd/
# appending:  xsgd
# page: 4 count: 192 , /currencies/taboo-token/
# appending:  taboo-token
# page: 4 count: 193 , /currencies/rsk-smart-bitcoin/
# appending:  rsk-smart-bitcoin
# page: 4 count: 194 , /currencies/zb-token/
# appending:  zb-token
# page: 4 count: 195 , /currencies/biswap/
# appending:  biswap
#
# _____NEXT PAGE_____
# page_num: 5
# https://coinmarketcap.com/?page=5
# page: 5 count: 66 , /currencies/gods-unchained/
# appending:  gods-unchained
# page: 5 count: 69 , /currencies/gods-unchained/?period=7d
# page: 5 count: 70 , /currencies/usdx-kava/
# appending:  usdx-kava
# page: 5 count: 73 , /currencies/usdx-kava/?period=7d
# page: 5 count: 74 , /currencies/bitshares/
# appending:  bitshares
# page: 5 count: 77 , /currencies/bitshares/?period=7d
# page: 5 count: 78 , /currencies/balancer/
# appending:  balancer
# page: 5 count: 81 , /currencies/balancer/?period=7d
# page: 5 count: 82 , /currencies/haven-protocol/
# appending:  haven-protocol
# page: 5 count: 85 , /currencies/haven-protocol/?period=7d
# page: 5 count: 86 , /currencies/thunder-token/
# appending:  thunder-token
# page: 5 count: 89 , /currencies/thunder-token/?period=7d
# page: 5 count: 90 , /currencies/strike/
# appending:  strike
# page: 5 count: 93 , /currencies/strike/?period=7d
# page: 5 count: 94 , /currencies/irisnet/
# appending:  irisnet
# page: 5 count: 97 , /currencies/irisnet/?period=7d
# page: 5 count: 98 , /currencies/clover/
# appending:  clover
# page: 5 count: 101 , /currencies/clover/?period=7d
# page: 5 count: 102 , /currencies/hoge-finance/
# appending:  hoge-finance
# page: 5 count: 105 , /currencies/hoge-finance/?period=7d
# page: 5 count: 106 , /currencies/mixmarvel/
# appending:  mixmarvel
# page: 5 count: 107 , /currencies/lto-network/
# appending:  lto-network
# page: 5 count: 108 , /currencies/cocos-bcx/
# appending:  cocos-bcx
# page: 5 count: 109 , /currencies/impossible-decentralized-incubator-access/
# appending:  impossible-decentralized-incubator-access
# page: 5 count: 110 , /currencies/klever/
# appending:  klever
# page: 5 count: 111 , /currencies/ampleforth-governance-token/
# appending:  ampleforth-governance-token
# page: 5 count: 112 , /currencies/glitch/
# appending:  glitch
# page: 5 count: 113 , /currencies/mainframe/
# appending:  mainframe
# page: 5 count: 114 , /currencies/carry/
# appending:  carry
# page: 5 count: 115 , /currencies/cyclub/
# appending:  cyclub
# page: 5 count: 116 , /currencies/mxc/
# appending:  mxc
# page: 5 count: 117 , /currencies/yearn-finance-ii/
# appending:  yearn-finance-ii
# page: 5 count: 118 , /currencies/atari-token/
# appending:  atari-token
# page: 5 count: 119 , /currencies/biopassport-token/
# appending:  biopassport-token
# page: 5 count: 120 , /currencies/cvault-finance/
# appending:  cvault-finance
# page: 5 count: 121 , /currencies/shiden-network/
# appending:  shiden-network
# page: 5 count: 122 , /currencies/splintershards/
# appending:  splintershards
# page: 5 count: 123 , /currencies/ankreth/
# appending:  ankreth
# page: 5 count: 124 , /currencies/lgcy-network/
# appending:  lgcy-network
# page: 5 count: 125 , /currencies/moss-coin/
# appending:  moss-coin
# page: 5 count: 126 , /currencies/hunt/
# appending:  hunt
# page: 5 count: 127 , /currencies/milk-alliance/
# appending:  milk-alliance
# page: 5 count: 128 , /currencies/safe/
# appending:  safe
# page: 5 count: 129 , /currencies/komodo/
# appending:  komodo
# page: 5 count: 130 , /currencies/barnbridge/
# appending:  barnbridge
# page: 5 count: 131 , /currencies/zkswap/
# appending:  zkswap
# page: 5 count: 132 , /currencies/chimpion/
# appending:  chimpion
# page: 5 count: 133 , /currencies/vvs-finance/
# appending:  vvs-finance
# page: 5 count: 134 , /currencies/tranchess/
# appending:  tranchess
# page: 5 count: 135 , /currencies/whale/
# appending:  whale
# page: 5 count: 136 , /currencies/dusk-network/
# appending:  dusk-network
# page: 5 count: 137 , /currencies/wrapped-nxm/
# appending:  wrapped-nxm
# page: 5 count: 138 , /currencies/ssv-network/
# appending:  ssv-network
# page: 5 count: 139 , /currencies/loom-network/
# appending:  loom-network
# page: 5 count: 140 , /currencies/boringdao/
# appending:  boringdao
# page: 5 count: 141 , /currencies/susd/
# appending:  susd
# page: 5 count: 142 , /currencies/sentinel/
# appending:  sentinel
# page: 5 count: 143 , /currencies/travala/
# appending:  travala
# page: 5 count: 144 , /currencies/newscrypto/
# appending:  newscrypto
# page: 5 count: 145 , /currencies/akropolis/
# appending:  akropolis
# page: 5 count: 146 , /currencies/alpha-quark-token/
# appending:  alpha-quark-token
# page: 5 count: 147 , /currencies/propy/
# appending:  propy
# page: 5 count: 148 , /currencies/streamr/
# appending:  streamr
# page: 5 count: 149 , /currencies/define/
# appending:  define
# page: 5 count: 150 , /currencies/ramp/
# appending:  ramp
# page: 5 count: 151 , /currencies/karura/
# appending:  karura
# page: 5 count: 152 , /currencies/troy/
# appending:  troy
# page: 5 count: 153 , /currencies/ethereum-swarm/
# appending:  ethereum-swarm
# page: 5 count: 154 , /currencies/celo-dollar/
# appending:  celo-dollar
# page: 5 count: 155 , /currencies/aergo/
# appending:  aergo
# page: 5 count: 156 , /currencies/bluzelle/
# appending:  bluzelle
# page: 5 count: 157 , /currencies/fox-token/
# appending:  fox-token
# page: 5 count: 158 , /currencies/marinade/
# appending:  marinade
# page: 5 count: 159 , /currencies/monacoin/
# appending:  monacoin
# page: 5 count: 160 , /currencies/starterra/
# appending:  starterra
# page: 5 count: 161 , /currencies/liquity/
# appending:  liquity
# page: 5 count: 162 , /currencies/aion/
# appending:  aion
# page: 5 count: 163 , /currencies/tellor/
# appending:  tellor
# page: 5 count: 164 , /currencies/quickswap/
# appending:  quickswap
# page: 5 count: 165 , /currencies/parsiq/
# appending:  parsiq
# page: 5 count: 166 , /currencies/apeswap-finance/
# appending:  apeswap-finance
# page: 5 count: 167 , /currencies/bella-protocol/
# appending:  bella-protocol
# page: 5 count: 168 , /currencies/rarible/
# appending:  rarible
# page: 5 count: 169 , /currencies/pangolin/
# appending:  pangolin
# page: 5 count: 170 , /currencies/bzx-protocol/
# appending:  bzx-protocol
# page: 5 count: 171 , /currencies/urus/
# appending:  urus
# page: 5 count: 172 , /currencies/dia/
# appending:  dia
# page: 5 count: 173 , /currencies/newyork-exchange/
# appending:  newyork-exchange
# page: 5 count: 174 , /currencies/beefy-finance/
# appending:  beefy-finance
# page: 5 count: 175 , /currencies/presearch/
# appending:  presearch
# page: 5 count: 176 , /currencies/cudos/
# appending:  cudos
# page: 5 count: 177 , /currencies/district0x/
# appending:  district0x
# page: 5 count: 178 , /currencies/shyft-network/
# appending:  shyft-network
# page: 5 count: 179 , /currencies/aleph-im/
# appending:  aleph-im
# page: 5 count: 180 , /currencies/keeperdao/
# appending:  keeperdao
# page: 5 count: 181 , /currencies/stasis-euro/
# appending:  stasis-euro
# page: 5 count: 182 , /currencies/adx-net/
# appending:  adx-net
# page: 5 count: 183 , /currencies/venus-usdc/
# appending:  venus-usdc
# page: 5 count: 184 , /currencies/freeway-token/
# appending:  freeway-token
# page: 5 count: 185 , /currencies/venus-xvs/
# appending:  venus-xvs
# page: 5 count: 186 , /currencies/sentinel-protocol/
# appending:  sentinel-protocol
# page: 5 count: 187 , /currencies/alpaca-finance/
# appending:  alpaca-finance
# page: 5 count: 188 , /currencies/crabada/
# appending:  crabada
# page: 5 count: 189 , /currencies/firo/
# appending:  firo
# page: 5 count: 190 , /currencies/vai/
# appending:  vai
# page: 5 count: 191 , /currencies/xdai/
# appending:  xdai
# page: 5 count: 192 , /currencies/hard-protocol/
# appending:  hard-protocol
# page: 5 count: 193 , /currencies/oxygen/
# appending:  oxygen
# page: 5 count: 194 , /currencies/lido-dao/
# appending:  lido-dao
# page: 5 count: 195 , /currencies/adshares/
# appending:  adshares
#
# _____NEXT PAGE_____
# page_num: 6
# https://coinmarketcap.com/?page=6
# page: 6 count: 66 , /currencies/assemble-protocol/
# appending:  assemble-protocol
# page: 6 count: 69 , /currencies/assemble-protocol/?period=7d
# page: 6 count: 70 , /currencies/refereum/
# appending:  refereum
# page: 6 count: 73 , /currencies/refereum/?period=7d
# page: 6 count: 74 , /currencies/xenioscoin/
# appending:  xenioscoin
# page: 6 count: 77 , /currencies/xenioscoin/?period=7d
# page: 6 count: 78 , /currencies/suku/
# appending:  suku
# page: 6 count: 81 , /currencies/suku/?period=7d
# page: 6 count: 82 , /currencies/elitium/
# appending:  elitium
# page: 6 count: 85 , /currencies/elitium/?period=7d
# page: 6 count: 86 , /currencies/math/
# appending:  math
# page: 6 count: 89 , /currencies/math/?period=7d
# page: 6 count: 90 , /currencies/bosagora/
# appending:  bosagora
# page: 6 count: 93 , /currencies/bosagora/?period=7d
# page: 6 count: 94 , /currencies/asch/
# appending:  asch
# page: 6 count: 96 , /currencies/asch/?period=7d
# page: 6 count: 97 , /currencies/hyperdao/
# appending:  hyperdao
# page: 6 count: 100 , /currencies/hyperdao/?period=7d
# page: 6 count: 101 , /currencies/ribbon-finance/
# appending:  ribbon-finance
# page: 6 count: 104 , /currencies/ribbon-finance/?period=7d
# page: 6 count: 105 , /currencies/mantra-dao/
# appending:  mantra-dao
# page: 6 count: 106 , /currencies/mithril/
# appending:  mithril
# page: 6 count: 107 , /currencies/elastos/
# appending:  elastos
# page: 6 count: 108 , /currencies/tokenpocket/
# appending:  tokenpocket
# page: 6 count: 109 , /currencies/moviebloc/
# appending:  moviebloc
# page: 6 count: 110 , /currencies/dad/
# appending:  dad
# page: 6 count: 111 , /currencies/dego-finance/
# appending:  dego-finance
# page: 6 count: 112 , /currencies/gas/
# appending:  gas
# page: 6 count: 113 , /currencies/revv/
# appending:  revv
# page: 6 count: 114 , /currencies/beyond-protocol/
# appending:  beyond-protocol
# page: 6 count: 115 , /currencies/flamingo/
# appending:  flamingo
# page: 6 count: 116 , /currencies/rchain/
# appending:  rchain
# page: 6 count: 117 , /currencies/groestlcoin/
# appending:  groestlcoin
# page: 6 count: 118 , /currencies/benqi/
# appending:  benqi
# page: 6 count: 119 , /currencies/harvest-finance/
# appending:  harvest-finance
# page: 6 count: 120 , /currencies/sifchain/
# appending:  sifchain
# page: 6 count: 121 , /currencies/paid-network/
# appending:  paid-network
# page: 6 count: 122 , /currencies/torum/
# appending:  torum
# page: 6 count: 123 , /currencies/vempire-ddao/
# appending:  vempire-ddao
# page: 6 count: 124 , /currencies/unifty/
# appending:  unifty
# page: 6 count: 125 , /currencies/doge-dash/
# appending:  doge-dash
# page: 6 count: 126 , /currencies/vegaprotocol/
# appending:  vegaprotocol
# page: 6 count: 127 , /currencies/bread/
# appending:  bread
# page: 6 count: 128 , /currencies/frontier/
# appending:  frontier
# page: 6 count: 129 , /currencies/contentos/
# appending:  contentos
# page: 6 count: 130 , /currencies/tokenlon-network-token/
# appending:  tokenlon-network-token
# page: 6 count: 131 , /currencies/strong/
# appending:  strong
# page: 6 count: 132 , /currencies/rai/
# appending:  rai
# page: 6 count: 133 , /currencies/marlin/
# appending:  marlin
# page: 6 count: 134 , /currencies/energi/
# appending:  energi
# page: 6 count: 135 , /currencies/kryll/
# appending:  kryll
# page: 6 count: 136 , /currencies/tnc-coin/
# appending:  tnc-coin
# page: 6 count: 137 , /currencies/saito/
# appending:  saito
# page: 6 count: 138 , /currencies/metronome/
# appending:  metronome
# page: 6 count: 139 , /currencies/edgeware/
# appending:  edgeware
# page: 6 count: 140 , /currencies/waltonchain/
# appending:  waltonchain
# page: 6 count: 141 , /currencies/hackenai/
# appending:  hackenai
# page: 6 count: 142 , /currencies/chain-guardians/
# appending:  chain-guardians
# page: 6 count: 143 , /currencies/bytom/
# appending:  bytom
# page: 6 count: 144 , /currencies/firmachain/
# appending:  firmachain
# page: 6 count: 145 , /currencies/bytecoin-bcn/
# appending:  bytecoin-bcn
# page: 6 count: 146 , /currencies/pac-protocol/
# appending:  pac-protocol
# page: 6 count: 147 , /currencies/videocoin/
# appending:  videocoin
# page: 6 count: 148 , /currencies/darma-cash/
# appending:  darma-cash
# page: 6 count: 149 , /currencies/selfkey/
# appending:  selfkey
# page: 6 count: 150 , /currencies/digixdao/
# appending:  digixdao
# page: 6 count: 151 , /currencies/bitmart-token/
# appending:  bitmart-token
# page: 6 count: 152 , /currencies/polkabridge/
# appending:  polkabridge
# page: 6 count: 153 , /currencies/position-exchange/
# appending:  position-exchange
# page: 6 count: 154 , /currencies/kava-swap/
# appending:  kava-swap
# page: 6 count: 155 , /currencies/velo/
# appending:  velo
# page: 6 count: 156 , /currencies/steem-dollars/
# appending:  steem-dollars
# page: 6 count: 157 , /currencies/rainicorn/
# appending:  rainicorn
# page: 6 count: 158 , /currencies/sora/
# appending:  sora
# page: 6 count: 159 , /currencies/valobit/
# appending:  valobit
# page: 6 count: 160 , /currencies/redd/
# appending:  redd
# page: 6 count: 161 , /currencies/fio-protocol/
# appending:  fio-protocol
# page: 6 count: 162 , /currencies/qcash/
# appending:  qcash
# page: 6 count: 163 , /currencies/six/
# appending:  six
# page: 6 count: 164 , /currencies/gny/
# appending:  gny
# page: 6 count: 165 , /currencies/hegic/
# appending:  hegic
# page: 6 count: 166 , /currencies/polkafoundry/
# appending:  polkafoundry
# page: 6 count: 167 , /currencies/polkadex/
# appending:  polkadex
# page: 6 count: 168 , /currencies/galaxy-heroes-coin/
# appending:  galaxy-heroes-coin
# page: 6 count: 169 , /currencies/coinex-token/
# appending:  coinex-token
# page: 6 count: 170 , /currencies/openocean/
# appending:  openocean
# page: 6 count: 171 , /currencies/starship/
# appending:  starship
# page: 6 count: 172 , /currencies/kleros/
# appending:  kleros
# page: 6 count: 173 , /currencies/dock/
# appending:  dock
# page: 6 count: 174 , /currencies/multivac/
# appending:  multivac
# page: 6 count: 175 , /currencies/aeternity/
# appending:  aeternity
# page: 6 count: 176 , /currencies/nimiq/
# appending:  nimiq
# page: 6 count: 177 , /currencies/beam/
# appending:  beam
# page: 6 count: 178 , /currencies/adapad/
# appending:  adapad
# page: 6 count: 179 , /currencies/veruscoin/
# appending:  veruscoin
# page: 6 count: 180 , /currencies/new-bitshares/
# appending:  new-bitshares
# page: 6 count: 181 , /currencies/zimbocash/
# appending:  zimbocash
# page: 6 count: 182 , /currencies/dextools/
# appending:  dextools
# page: 6 count: 183 , /currencies/maro/
# appending:  maro
# page: 6 count: 184 , /currencies/maple/
# appending:  maple
# page: 6 count: 185 , /currencies/efforce/
# appending:  efforce
# page: 6 count: 186 , /currencies/gomining-token/
# appending:  gomining-token
# page: 6 count: 187 , /currencies/burger-swap/
# appending:  burger-swap
# page: 6 count: 188 , /currencies/yield-app/
# appending:  yield-app
# page: 6 count: 189 , /currencies/grid/
# appending:  grid
# page: 6 count: 190 , /currencies/btu-protocol/
# appending:  btu-protocol
# page: 6 count: 191 , /currencies/bepro-network/
# appending:  bepro-network
# page: 6 count: 192 , /currencies/bounce-token/
# appending:  bounce-token
# page: 6 count: 193 , /currencies/unifi-protocol-dao/
# appending:  unifi-protocol-dao
# page: 6 count: 194 , /currencies/gamezone/
# appending:  gamezone
#
# _____NEXT PAGE_____
# page_num: 7
# https://coinmarketcap.com/?page=7
# page: 7 count: 66 , /currencies/airswap/
# appending:  airswap
# page: 7 count: 69 , /currencies/airswap/?period=7d
# page: 7 count: 70 , /currencies/apollo-currency/
# appending:  apollo-currency
# page: 7 count: 73 , /currencies/apollo-currency/?period=7d
# page: 7 count: 74 , /currencies/mimblewimblecoin/
# appending:  mimblewimblecoin
# page: 7 count: 77 , /currencies/mimblewimblecoin/?period=7d
# page: 7 count: 78 , /currencies/civilization/
# appending:  civilization
# page: 7 count: 81 , /currencies/civilization/?period=7d
# page: 7 count: 82 , /currencies/mint-club/
# appending:  mint-club
# page: 7 count: 85 , /currencies/mint-club/?period=7d
# page: 7 count: 86 , /currencies/revolution-populi/
# appending:  revolution-populi
# page: 7 count: 89 , /currencies/revolution-populi/?period=7d
# page: 7 count: 90 , /currencies/dora-factory/
# appending:  dora-factory
# page: 7 count: 93 , /currencies/dora-factory/?period=7d
# page: 7 count: 94 , /currencies/amo-coin/
# appending:  amo-coin
# page: 7 count: 97 , /currencies/amo-coin/?period=7d
# page: 7 count: 98 , /currencies/fusion/
# appending:  fusion
# page: 7 count: 101 , /currencies/fusion/?period=7d
# page: 7 count: 102 , /currencies/latoken/
# appending:  latoken
# page: 7 count: 105 , /currencies/latoken/?period=7d
# page: 7 count: 106 , /currencies/reflexer-ungovernance-token/
# appending:  reflexer-ungovernance-token
# page: 7 count: 107 , /currencies/cryptoplanes/
# appending:  cryptoplanes
# page: 7 count: 108 , /currencies/gameswap/
# appending:  gameswap
# page: 7 count: 109 , /currencies/faraland/
# appending:  faraland
# page: 7 count: 110 , /currencies/cellframe/
# appending:  cellframe
# page: 7 count: 111 , /currencies/stackos/
# appending:  stackos
# page: 7 count: 112 , /currencies/kylin/
# appending:  kylin
# page: 7 count: 113 , /currencies/venus-busd/
# appending:  venus-busd
# page: 7 count: 114 , /currencies/singularitydao/
# appending:  singularitydao
# page: 7 count: 115 , /currencies/vite/
# appending:  vite
# page: 7 count: 116 , /currencies/sharetoken/
# appending:  sharetoken
# page: 7 count: 117 , /currencies/milc-platform/
# appending:  milc-platform
# page: 7 count: 118 , /currencies/blockv/
# appending:  blockv
# page: 7 count: 119 , /currencies/electric-vehicle-zone/
# appending:  electric-vehicle-zone
# page: 7 count: 120 , /currencies/neutrino-system-base-token/
# appending:  neutrino-system-base-token
# page: 7 count: 121 , /currencies/basic/
# appending:  basic
# page: 7 count: 122 , /currencies/gamee/
# appending:  gamee
# page: 7 count: 123 , /currencies/hot-cross/
# appending:  hot-cross
# page: 7 count: 124 , /currencies/o3-swap/
# appending:  o3-swap
# page: 7 count: 125 , /currencies/mileverse/
# appending:  mileverse
# page: 7 count: 126 , /currencies/hamster/
# appending:  hamster
# page: 7 count: 127 , /currencies/paris-saint-germain-fan-token/
# appending:  paris-saint-germain-fan-token
# page: 7 count: 128 , /currencies/powerpool/
# appending:  powerpool
# page: 7 count: 129 , /currencies/covalent/
# appending:  covalent
# page: 7 count: 130 , /currencies/dexe/
# appending:  dexe
# page: 7 count: 131 , /currencies/crustnetwork/
# appending:  crustnetwork
# page: 7 count: 132 , /currencies/clearpool/
# appending:  clearpool
# page: 7 count: 133 , /currencies/veritaseum/
# appending:  veritaseum
# page: 7 count: 134 , /currencies/wirex-token/
# appending:  wirex-token
# page: 7 count: 135 , /currencies/nuls/
# appending:  nuls
# page: 7 count: 136 , /currencies/pivx/
# appending:  pivx
# page: 7 count: 137 , /currencies/auto/
# appending:  auto
# page: 7 count: 138 , /currencies/nftx/
# appending:  nftx
# page: 7 count: 139 , /currencies/stratos/
# appending:  stratos
# page: 7 count: 140 , /currencies/unfederalreserve/
# appending:  unfederalreserve
# page: 7 count: 141 , /currencies/torn/
# appending:  torn
# page: 7 count: 142 , /currencies/aragon-court/
# appending:  aragon-court
# page: 7 count: 143 , /currencies/pnetwork/
# appending:  pnetwork
# page: 7 count: 144 , /currencies/orion-money/
# appending:  orion-money
# page: 7 count: 145 , /currencies/axel/
# appending:  axel
# page: 7 count: 146 , /currencies/v-systems/
# appending:  v-systems
# page: 7 count: 147 , /currencies/the-force-protocol/
# appending:  the-force-protocol
# page: 7 count: 148 , /currencies/blockchain-monster-hunt/
# appending:  blockchain-monster-hunt
# page: 7 count: 149 , /currencies/deri-protocol/
# appending:  deri-protocol
# page: 7 count: 150 , /currencies/dragonchain/
# appending:  dragonchain
# page: 7 count: 151 , /currencies/perlin/
# appending:  perlin
# page: 7 count: 152 , /currencies/epic-cash/
# appending:  epic-cash
# page: 7 count: 153 , /currencies/measurable-data-token/
# appending:  measurable-data-token
# page: 7 count: 154 , /currencies/solve/
# appending:  solve
# page: 7 count: 155 , /currencies/counterparty/
# appending:  counterparty
# page: 7 count: 156 , /currencies/cargox/
# appending:  cargox
# page: 7 count: 157 , /currencies/dehub/
# appending:  dehub
# page: 7 count: 158 , /currencies/hydra/
# appending:  hydra
# ...
# appending:  dar
# page: 48 count: 191 , /currencies/global-game-coin/
# appending:  global-game-coin
# page: 48 count: 192 , /currencies/dfx-finance/
# appending:  dfx-finance
# page: 48 count: 193 , /currencies/3x-long-vechain-token/
# appending:  3x-long-vechain-token
# page: 48 count: 194 , /currencies/ari10/
# appending:  ari10
# page: 48 count: 195 , /currencies/hedpay/
# appending:  hedpay
#
# _____NEXT PAGE_____
# page_num: 49
# https://coinmarketcap.com/?page=49
# page: 49 count: 66 , /currencies/ethos-project/
# appending:  ethos-project
# page: 49 count: 69 , /currencies/ethos-project/?period=7d
# page: 49 count: 70 , /currencies/shibapad/
# appending:  shibapad
# page: 49 count: 73 , /currencies/shibapad/?period=7d
# page: 49 count: 74 , /currencies/mytoken/
# appending:  mytoken
# page: 49 count: 77 , /currencies/mytoken/?period=7d
# page: 49 count: 78 , /currencies/baby-moon-floki/
# appending:  baby-moon-floki
# page: 49 count: 81 , /currencies/baby-moon-floki/?period=7d
# page: 49 count: 82 , /currencies/pledge-coin/
# appending:  pledge-coin
# page: 49 count: 85 , /currencies/pledge-coin/?period=7d
# page: 49 count: 86 , /currencies/pooltogether/
# appending:  pooltogether
# page: 49 count: 89 , /currencies/pooltogether/?period=7d
# page: 49 count: 90 , /currencies/fanscoin/
# appending:  fanscoin
# page: 49 count: 93 , /currencies/fanscoin/?period=7d
# page: 49 count: 94 , /currencies/nafty/
# appending:  nafty
# page: 49 count: 97 , /currencies/nafty/?period=7d
# page: 49 count: 98 , /currencies/alinx/
# appending:  alinx
# page: 49 count: 101 , /currencies/alinx/?period=7d
# page: 49 count: 102 , /currencies/tokenplace/
# appending:  tokenplace
# page: 49 count: 105 , /currencies/tokenplace/?period=7d
# page: 49 count: 106 , /currencies/the-three-kingdoms-chi/
# appending:  the-three-kingdoms-chi
# page: 49 count: 107 , /currencies/liquidchain/
# appending:  liquidchain
# page: 49 count: 108 , /currencies/envoy-network/
# appending:  envoy-network
# page: 49 count: 109 , /currencies/pyroblock/
# appending:  pyroblock
# page: 49 count: 110 , /currencies/elephant-money/
# appending:  elephant-money
# page: 49 count: 111 , /currencies/step-hero-step/
# appending:  step-hero-step
# page: 49 count: 112 , /currencies/eternalgirl/
# appending:  eternalgirl
# page: 49 count: 113 , /currencies/yearnagnostic-finance/
# appending:  yearnagnostic-finance
# page: 49 count: 114 , /currencies/snt/
# appending:  snt
# page: 49 count: 115 , /currencies/gods-and-legends/
# appending:  gods-and-legends
# page: 49 count: 116 , /currencies/royal-protocol/
# appending:  royal-protocol
# page: 49 count: 117 , /currencies/deez-nuts/
# appending:  deez-nuts
# page: 49 count: 118 , /currencies/polkaparty/
# appending:  polkaparty
# page: 49 count: 119 , /currencies/supersonic-finance/
# appending:  supersonic-finance
# page: 49 count: 120 , /currencies/catbonk/
# appending:  catbonk
# page: 49 count: 121 , /currencies/starname/
# appending:  starname
# page: 49 count: 122 , /currencies/airnfts/
# appending:  airnfts
# page: 49 count: 123 , /currencies/gremlins-finance/
# appending:  gremlins-finance
# page: 49 count: 124 , /currencies/super-bitcoin/
# appending:  super-bitcoin
# page: 49 count: 125 , /currencies/mirai-labs/
# appending:  mirai-labs
# page: 49 count: 126 , /currencies/echo-tech-coin/
# appending:  echo-tech-coin
# page: 49 count: 127 , /currencies/metaraca/
# appending:  metaraca
# page: 49 count: 128 , /currencies/black-lemon/
# appending:  black-lemon
# page: 49 count: 129 , /currencies/memekiller/
# appending:  memekiller
# page: 49 count: 130 , /currencies/croxswap/
# appending:  croxswap
# page: 49 count: 131 , /currencies/tetu/
# appending:  tetu
# page: 49 count: 132 , /currencies/dcoin-token/
# appending:  dcoin-token
# page: 49 count: 133 , /currencies/dogebull/
# appending:  dogebull
# page: 49 count: 134 , /currencies/findshibby/
# appending:  findshibby
# page: 49 count: 135 , /currencies/simbcoin-swap/
# appending:  simbcoin-swap
# page: 49 count: 136 , /currencies/idle-mystic/
# appending:  idle-mystic
# page: 49 count: 137 , /currencies/blackpool/
# appending:  blackpool
# page: 49 count: 138 , /currencies/bzzone/
# appending:  bzzone
# page: 49 count: 139 , /currencies/coin-of-champions/
# appending:  coin-of-champions
# page: 49 count: 140 , /currencies/planet-finance/
# appending:  planet-finance
# page: 49 count: 141 , /currencies/metaaxis/
# appending:  metaaxis
# page: 49 count: 142 , /currencies/wault-finance-new/
# appending:  wault-finance-new
# page: 49 count: 143 , /currencies/fibswap-dex/
# appending:  fibswap-dex
# page: 49 count: 144 , /currencies/shiba-inu-billionaire/
# appending:  shiba-inu-billionaire
# page: 49 count: 145 , /currencies/arbis-finance/
# appending:  arbis-finance
# page: 49 count: 146 , /currencies/solomon-defi/
# appending:  solomon-defi
# page: 49 count: 147 , /currencies/algopad/
# appending:  algopad
# page: 49 count: 148 , /currencies/3x-long-bitcoin-cash-token/
# appending:  3x-long-bitcoin-cash-token
# page: 49 count: 149 , /currencies/caash/
# appending:  caash
# page: 49 count: 150 , /currencies/trueburn/
# appending:  trueburn
# page: 49 count: 151 , /currencies/quidax/
# appending:  quidax
# page: 49 count: 152 , /currencies/bsc-memepad/
# appending:  bsc-memepad
# page: 49 count: 153 , /currencies/batman/
# appending:  batman
# page: 49 count: 154 , /currencies/cross-chain-bridge-token/
# appending:  cross-chain-bridge-token
# page: 49 count: 155 , /currencies/hodl-finance/
# appending:  hodl-finance
# page: 49 count: 156 , /currencies/etherrock-72/
# appending:  etherrock-72
# page: 49 count: 157 , /currencies/liquidity-accelerator-token/
# appending:  liquidity-accelerator-token
# page: 49 count: 158 , /currencies/didcoin/
# appending:  didcoin
# page: 49 count: 159 , /currencies/timechain-swap-token/
# appending:  timechain-swap-token
# page: 49 count: 160 , /currencies/exzocoin-2/
# appending:  exzocoin-2
# page: 49 count: 161 , /currencies/munch-token/
# appending:  munch-token
# page: 49 count: 162 , /currencies/poomoon/
# appending:  poomoon
# page: 49 count: 163 , /currencies/qian-kun/
# appending:  qian-kun
# page: 49 count: 164 , /currencies/pop/
# appending:  pop
# page: 49 count: 165 , /currencies/sherpa/
# appending:  sherpa
# page: 49 count: 166 , /currencies/orica/
# appending:  orica
# page: 49 count: 167 , /currencies/morpher/
# appending:  morpher
# page: 49 count: 168 , /currencies/corginftgame/
# appending:  corginftgame
# page: 49 count: 169 , /currencies/strong-inu/
# appending:  strong-inu
# page: 49 count: 170 , /currencies/racex/
# appending:  racex
# page: 49 count: 171 , /currencies/gemit-app/
# appending:  gemit-app
# page: 49 count: 172 , /currencies/algebra/
# appending:  algebra
# page: 49 count: 173 , /currencies/satopay-network/
# appending:  satopay-network
# page: 49 count: 174 , /currencies/mars/
# appending:  mars
# page: 49 count: 175 , /currencies/less-network/
# appending:  less-network
# page: 49 count: 176 , /currencies/hippo-token/
# appending:  hippo-token
# page: 49 count: 177 , /currencies/hamdan-coin/
# appending:  hamdan-coin
# page: 49 count: 178 , /currencies/swanlana/
# appending:  swanlana
# page: 49 count: 179 , /currencies/linktoken/
# appending:  linktoken
# page: 49 count: 180 , /currencies/tomi/
# appending:  tomi
# page: 49 count: 181 , /currencies/boda-token/
# appending:  boda-token
# page: 49 count: 182 , /currencies/we-love-gm/
# appending:  we-love-gm
# page: 49 count: 183 , /currencies/phoswap/
# appending:  phoswap
# page: 49 count: 184 , /currencies/stabledoc/
# appending:  stabledoc
# page: 49 count: 185 , /currencies/crystal/
# appending:  crystal
# page: 49 count: 186 , /currencies/berry/
# appending:  berry
# page: 49 count: 187 , /currencies/shining-crystal-shard/
# appending:  shining-crystal-shard
# page: 49 count: 188 , /currencies/witch-token/
# appending:  witch-token
# page: 49 count: 189 , /currencies/pilot/
# appending:  pilot
# page: 49 count: 190 , /currencies/potentiam/
# appending:  potentiam
# page: 49 count: 191 , /currencies/ndau/
# appending:  ndau
# page: 49 count: 192 , /currencies/goldex-token/
# appending:  goldex-token
# page: 49 count: 193 , /currencies/spooky-shiba/
# appending:  spooky-shiba
# page: 49 count: 194 , /currencies/bincentive/
# appending:  bincentive
# page: 49 count: 195 , /currencies/wardenswap/
# appending:  wardenswap
#
# _____NEXT PAGE_____
# page_num: 50
# https://coinmarketcap.com/?page=50
# page: 50 count: 66 , /currencies/dynasty-global-investments/
# appending:  dynasty-global-investments
# page: 50 count: 69 , /currencies/dynasty-global-investments/?period=7d
# page: 50 count: 70 , /currencies/multi-farm-capital/
# appending:  multi-farm-capital
# page: 50 count: 73 , /currencies/multi-farm-capital/?period=7d
# page: 50 count: 74 , /currencies/vindax-coin/
# appending:  vindax-coin
# page: 50 count: 77 , /currencies/vindax-coin/?period=7d
# page: 50 count: 78 , /currencies/d-skyscraper/
# appending:  d-skyscraper
# page: 50 count: 81 , /currencies/d-skyscraper/?period=7d
# page: 50 count: 82 , /currencies/nvidia-tokenized-stock-ftx/
# appending:  nvidia-tokenized-stock-ftx
# page: 50 count: 85 , /currencies/nvidia-tokenized-stock-ftx/?period=7d
# page: 50 count: 86 , /currencies/pika/
# appending:  pika
# page: 50 count: 89 , /currencies/pika/?period=7d
# page: 50 count: 90 , /currencies/xusd-stable/
# appending:  xusd-stable
# page: 50 count: 93 , /currencies/xusd-stable/?period=7d
# page: 50 count: 94 , /currencies/hina-inu/
# appending:  hina-inu
# page: 50 count: 97 , /currencies/hina-inu/?period=7d
# page: 50 count: 98 , /currencies/hodler-heroes-nft/
# appending:  hodler-heroes-nft
# page: 50 count: 101 , /currencies/hodler-heroes-nft/?period=7d
# page: 50 count: 102 , /currencies/ki-foundation/
# appending:  ki-foundation
# page: 50 count: 105 , /currencies/ki-foundation/?period=7d
# page: 50 count: 106 , /currencies/crystal-pro/
# appending:  crystal-pro
# page: 50 count: 107 , /currencies/u-coin/
# appending:  u-coin
# page: 50 count: 108 , /currencies/flavorsbsc/
# appending:  flavorsbsc
# page: 50 count: 109 , /currencies/taptoken/
# appending:  taptoken
# page: 50 count: 110 , /currencies/armor-nxm/
# appending:  armor-nxm
# page: 50 count: 111 , /currencies/grayscale-bitcoin-trust-tokenized-stock-ftx/
# appending:  grayscale-bitcoin-trust-tokenized-stock-ftx
# page: 50 count: 112 , /currencies/demeter-usd/
# appending:  demeter-usd
# page: 50 count: 113 , /currencies/drivenx/
# appending:  drivenx
# page: 50 count: 114 , /currencies/elondoge/
# appending:  elondoge
# page: 50 count: 115 , /currencies/society-of-galactic-exploration/
# appending:  society-of-galactic-exploration
# page: 50 count: 116 , /currencies/gysr/
# appending:  gysr
# page: 50 count: 117 , /currencies/animal-token/
# appending:  animal-token
# page: 50 count: 118 , /currencies/pulsedoge/
# appending:  pulsedoge
# page: 50 count: 119 , /currencies/my-pet-social/
# appending:  my-pet-social
# page: 50 count: 120 , /currencies/decredit/
# appending:  decredit
# page: 50 count: 121 , /currencies/deus-finance-2/
# appending:  deus-finance-2
# page: 50 count: 122 , /currencies/brave/
# appending:  brave
# page: 50 count: 123 , /currencies/melalie/
# appending:  melalie
# page: 50 count: 124 , /currencies/future1coin/
# appending:  future1coin
# page: 50 count: 125 , /currencies/flux-protocol/
# appending:  flux-protocol
# page: 50 count: 126 , /currencies/digital-fitness/
# appending:  digital-fitness
# page: 50 count: 127 , /currencies/axial/
# appending:  axial
# page: 50 count: 128 , /currencies/gold-zilla/
# appending:  gold-zilla
# page: 50 count: 129 , /currencies/beekan/
# appending:  beekan
# page: 50 count: 130 , /currencies/matrix-protocol/
# appending:  matrix-protocol
# page: 50 count: 131 , /currencies/3x-long-dragon-index-token/
# appending:  3x-long-dragon-index-token
# page: 50 count: 132 , /currencies/akoin/
# appending:  akoin
# page: 50 count: 133 , /currencies/vkenaf/
# appending:  vkenaf
# page: 50 count: 134 , /currencies/community-doge-coin/
# appending:  community-doge-coin
# page: 50 count: 135 , /currencies/maskdoge/
# appending:  maskdoge
# page: 50 count: 136 , /currencies/squidanomics/
# appending:  squidanomics
# page: 50 count: 137 , /currencies/fuma-finance/
# appending:  fuma-finance
# page: 50 count: 138 , /currencies/bulldogswap/
# appending:  bulldogswap
# page: 50 count: 139 , /currencies/artex/
# appending:  artex
# page: 50 count: 140 , /currencies/payrue-propel/
# appending:  payrue-propel
# page: 50 count: 141 , /currencies/arcx-token/
# appending:  arcx-token
# page: 50 count: 142 , /currencies/baby-bitcoin/
# appending:  baby-bitcoin
# page: 50 count: 143 , /currencies/artificial-intelligence/
# appending:  artificial-intelligence
# page: 50 count: 144 , /currencies/scorpion-finance/
# appending:  scorpion-finance
# page: 50 count: 145 , /currencies/mushu-finance/
# appending:  mushu-finance
# page: 50 count: 146 , /currencies/rowan-token/
# appending:  rowan-token
# page: 50 count: 147 , /currencies/idoscan/
# appending:  idoscan
# page: 50 count: 148 , /currencies/utilies-cryptocurrency-exchange/
# appending:  utilies-cryptocurrency-exchange
# page: 50 count: 149 , /currencies/nftstyle/
# appending:  nftstyle
# page: 50 count: 150 , /currencies/piggy-finance/
# appending:  piggy-finance
# page: 50 count: 151 , /currencies/plutos-network/
# appending:  plutos-network
# page: 50 count: 152 , /currencies/warlockbnb/
# appending:  warlockbnb
# page: 50 count: 153 , /currencies/oro/
# appending:  oro
# page: 50 count: 154 , /currencies/swapdex/
# appending:  swapdex
# page: 50 count: 155 , /currencies/polly-defi-nest/
# appending:  polly-defi-nest
# page: 50 count: 156 , /currencies/dart-inu/
# appending:  dart-inu
# page: 50 count: 157 , /currencies/surge-inu/
# appending:  surge-inu
# page: 50 count: 158 , /currencies/genesis-pool/
# appending:  genesis-pool
# page: 50 count: 159 , /currencies/defipie/
# appending:  defipie
# page: 50 count: 160 , /currencies/moma-protocol/
# appending:  moma-protocol
# page: 50 count: 161 , /currencies/dough/
# appending:  dough
# page: 50 count: 162 , /currencies/dogemoon/
# appending:  dogemoon
# page: 50 count: 163 , /currencies/degen-ape-club/
# appending:  degen-ape-club
# page: 50 count: 164 , /currencies/toolape/
# appending:  toolape
# page: 50 count: 165 , /currencies/unifi-protocol/
# appending:  unifi-protocol
# page: 50 count: 166 , /currencies/proswap/
# appending:  proswap
# page: 50 count: 167 , /currencies/frmx-token/
# appending:  frmx-token
# page: 50 count: 168 , /currencies/mmscash/
# appending:  mmscash
# page: 50 count: 169 , /currencies/elf-token/
# appending:  elf-token
# page: 50 count: 170 , /currencies/robo-inu-finance/
# appending:  robo-inu-finance
# page: 50 count: 171 , /currencies/jetswap-finance/
# appending:  jetswap-finance
# page: 50 count: 172 , /currencies/daohaus/
# appending:  daohaus
# page: 50 count: 173 , /currencies/nebulatoken/
# appending:  nebulatoken
# page: 50 count: 174 , /currencies/ttcoin/
# appending:  ttcoin
# page: 50 count: 175 , /currencies/blockmason-link/
# appending:  blockmason-link
# page: 50 count: 176 , /currencies/hoopoe/
# appending:  hoopoe
# page: 50 count: 177 , /currencies/electric-vehicle-direct-currency/
# appending:  electric-vehicle-direct-currency
# page: 50 count: 178 , /currencies/shiba-watch/
# appending:  shiba-watch
# page: 50 count: 179 , /currencies/baby-floki/
# appending:  baby-floki
# page: 50 count: 180 , /currencies/milkshakeswap-finance/
# appending:  milkshakeswap-finance
# page: 50 count: 181 , /currencies/polkatrain/
# appending:  polkatrain
# page: 50 count: 182 , /currencies/zufinance/
# appending:  zufinance
# page: 50 count: 183 , /currencies/spinada-cash/
# appending:  spinada-cash
# page: 50 count: 184 , /currencies/windoge95/
# appending:  windoge95
# page: 50 count: 185 , /currencies/fox-finance/
# appending:  fox-finance
# page: 50 count: 186 , /currencies/tiger-cub/
# appending:  tiger-cub
# page: 50 count: 187 , /currencies/eutaria/
# appending:  eutaria
# page: 50 count: 188 , /currencies/astronos/
# appending:  astronos
# page: 50 count: 189 , /currencies/matrixetf/
# appending:  matrixetf
# page: 50 count: 190 , /currencies/3x-long-trx-token/
# appending:  3x-long-trx-token
# page: 50 count: 191 , /currencies/tractor-joe/
# appending:  tractor-joe
# page: 50 count: 192 , /currencies/pinkslip-finance/
# appending:  pinkslip-finance
# page: 50 count: 193 , /currencies/ecofi/
# appending:  ecofi
# page: 50 count: 194 , /currencies/brandpad-finance/
# appending:  brandpad-finance
# page: 50 count: 195 , /currencies/facebook-tokenized-stock-ftx/
# appending:  facebook-tokenized-stock-ftx
#
# _____NEXT PAGE_____

# %%
cryp_list
# Out:
# ['bitcoin',
#  'ethereum',
#  'binance-coin',
#  'tether',
#  'solana',
#  'cardano',
#  'xrp',
#  'usd-coin',
#  'polkadot-new',
#  'dogecoin',
#  'avalanche',
#  'shiba-inu',
#  'terra-luna',
#  'crypto-com-coin',
#  'litecoin',
#  'polygon',
#  'wrapped-bitcoin',
#  'uniswap',
#  'binance-usd',
#  'chainlink',
#  'algorand',
#  'bitcoin-cash',
#  'axie-infinity',
#  'decentraland',
#  'stellar',
#  'vechain',
#  'internet-computer',
#  'elrond-egld',
#  'terrausd',
#  'filecoin',
#  'ftx-token',
#  'tron',
#  'theta',
#  'multi-collateral-dai',
#  'ethereum-classic',
#  'hedera',
#  'cosmos',
#  'bitcoin-bep2',
#  'the-sandbox',
#  'fantom',
#  'near-protocol',
#  'tezos',
#  'the-graph',
#  'gala',
#  'monero',
#  'helium',
#  'klaytn',
#  'eos',
#  'flow',
#  'iota',
#  'loopring',
#  'stacks',
#  'aave',
#  'pancakeswap',
#  'kusama',
#  'unus-sed-leo',
#  'bittorrent',
#  'zcash',
#  'maker',
#  'enjin-coin',
#  'harmony',
#  'thorchain',
#  'bitcoin-sv',
#  'ecash',
#  'kadena',
#  'neo',
#  'chiliz',
#  'amp',
#  'quant',
#  'waves',
#  'curve-dao-token',
#  'kucoin-token',
#  'basic-attention-token',
#  'holo',
#  'arweave',
#  'dash',
#  'celo',
#  'compound',
#  'theta-fuel',
#  'nexo',
#  'qtum',
#  'nem',
#  'okb',
#  'huobi-token',
#  'iotex',
#  'decred',
#  'mina',
#  'immutable-x',
#  'voyager-token',
#  'horizen',
#  'trueusd',
#  'audius',
#  'ankr',
#  'wax',
#  'icon',
#  'omg',
#  'siacoin',
#  'livepeer',
#  'ravencoin',
#  'oasis-network',
#  'xinfin',
#  'yearn-finance',
#  'zilliqa',
#  'bora',
#  'sushiswap',
#  '0x',
#  'bitcoin-gold',
#  'renbtc',
#  'bancor',
#  'revain',
#  'ren',
#  'celsius',
#  'paxos-standard',
#  'hive-blockchain',
#  'secret',
#  'dogelon',
#  'storj',
#  'nervos-network',
#  'synthetix-network-token',
#  'perpetual-protocol',
#  'velas',
#  'raydium',
#  'ontology',
#  'uma',
#  'skale-network',
#  'telcoin',
#  'serum',
#  'ocean-protocol',
#  'golem-network-tokens',
#  'dydx',
#  'request',
#  'iostoken',
#  'ceek-vr',
#  'digibyte',
#  'kava',
#  'moonriver',
#  'swissborg',
#  '1inch',
#  'polymath-network',
#  'gnosis-gno',
#  'celer-network',
#  'wink',
#  'xyo',
#  'myneighboralice',
#  'nucypher',
#  'reserve-rights',
#  'wootrade',
#  'origintrail',
#  'digitalbits',
#  'fetch',
#  'injective-protocol',
#  'casper',
#  'gatetoken',
#  'just',
#  'neutrino-usd',
#  'chromia',
#  'ultra',
#  'mdex',
#  'syscoin',
#  'cartesi',
#  'dent',
#  'lisk',
#  'function-x',
#  'swipe',
#  'dvision-network',
#  'zel',
#  'medibloc',
#  'alpha-finance-lab',
#  'fei-usd',
#  'coti',
#  'reef',
#  'wazirx',
#  'origin-protocol',
#  'verge',
#  'btc-standard-hashrate-token',
#  'civic',
#  'phantasma',
#  'ardor',
#  'vethor-token',
#  'nkn',
#  'status',
#  'bakerytoken',
#  'orchid',
#  'mx-token',
#  'polkastarter',
#  'rlc',
#  'bitcoin-diamond',
#  'divi',
#  'conflux-network',
#  'pax-gold',
#  'energy-web-token',
#  'ampleforth',
#  'badger-dao',
#  'stormx',
#  'ontology-gas',
#  'aelf',
#  'crypto-com',
#  'band-protocol',
#  'power-ledger',
#  'husd',
#  'hex',
#  'steth',
#  'wbnb',
#  'huobi-btc',
#  'symbol',
#  'wemix',
#  'youcash',
#  'link',
#  'safemoon',
#  'bitdao',
#  'creditcoin',
#  'ethereum-name-service',
#  'frax',
#  'illuvium',
#  'venus-bnb',
#  'apenft',
#  'rally',
#  'ecomi',
#  'mobilecoin',
#  'convex-finance',
#  'nxm',
#  'defichain',
#  'bloktopia',
#  'the-transfer-token',
#  'counos-x',
#  'radio-caca',
#  'render-token',
#  'sologenic',
#  'mobox',
#  'vulcan-forged-pyr',
#  'alitas',
#  'superfarm',
#  'jasmy',
#  'yooshi',
#  'liquity-usd',
#  'whitecoin',
#  'nano',
#  'anchor-protocol',
#  'star-link',
#  'coin98',
#  'yield-guild-games',
#  'playdapp',
#  'rocket-pool',
#  'tribe',
#  'bifrost',
#  'orbit-chain',
#  'keep-network',
#  'platon',
#  'persistence',
#  'mask-network',
#  'keystone-of-opportunity-knowledge',
#  'merit-circle',
#  'glitzkoin',
#  'wilder-world',
#  'rmrk',
#  'braintrust',
#  'joe',
#  'star-atlas',
#  'mines-of-dalarnia',
#  'deversifi',
#  'bonfida',
#  'hathor',
#  'bitpanda-ecosystem-token',
#  'wrapped-ncg',
#  'alien-worlds',
#  'trust-wallet-token',
#  'beta-finance',
#  'pundix-new',
#  'dao-maker',
#  'kyber-network-crystal-v2',
#  'redfox-labs',
#  'seedify-fund',
#  'centrality',
#  'kardiachain',
#  'chia-network',
#  'sun-token',
#  'pirate-chain',
#  'alchemix',
#  'vectorspace-ai',
#  'alchemy-pay',
#  'mango-markets',
#  'rari-governance-token',
#  'efinity',
#  'radix',
#  'anyswap',
#  'frax-share',
#  'radicle',
#  'humanscape',
#  'sovryn',
#  'lukso',
#  'bitmax-token',
#  'telos',
#  'idex',
#  'binaryx',
#  'orbs',
#  'safepal',
#  'stratis',
#  'sapphire',
#  'ark',
#  'steem',
#  'tomochain',
#  'unibright',
#  'prometeus',
#  'orion-protocol',
#  'venus',
#  'constellation',
#  'electroneum',
#  'verasity',
#  'terra-virtua-kolect',
#  'akash-network',
#  'augur',
#  'truefi-token',
#  'insure',
#  'numeraire',
#  'maidsafecoin',
#  'venus-btc',
#  'qredo',
#  'gitcoin',
#  'dawn-protocol',
#  'hedgetrade',
#  'singularitynet',
#  'somesing',
#  'mvl',
#  'abbc-coin',
#  'lcx',
#  'ellipsis',
#  'aavegotchi',
#  'ergo',
#  'funtoken',
#  'metadium',
#  'linear',
#  'hxro',
#  'keep3rv1',
#  'aragon',
#  'gamefi',
#  'mirror-protocol',
#  'star-atlas-polis',
#  'zenon',
#  'derace',
#  'samoyedcoin',
#  'c20',
#  'dero',
#  'aioz-network',
#  'defi-land',
#  'gemini-dollar',
#  'quarkchain',
#  'derivadao',
#  'proton',
#  'syntropy',
#  'molecular-future',
#  'standard-tokenization-protocol',
#  'kin',
#  'decentral-games',
#  'rsk-infrastructure-framework',
#  'metal',
#  'uquid-coin',
#  'handshake',
#  'everscale',
#  'centrifuge',
#  'automata-network',
#  'titanswap',
#  'venus-eth',
#  'defi-pulse-index',
#  'tether-gold',
#  'enzyme',
#  'deapcoin',
#  'solanium',
#  'rakon',
#  'everipedia',
#  'superrare',
#  'sport-and-leisure',
#  'tokocrypto',
#  'bscpad',
#  'certik',
#  'trustswap',
#  'smooth-love-potion',
#  'metisdao',
#  'api3',
#  'adventure-gold',
#  'boson-protocol',
#  'bloomzed-token',
#  'phala-network',
#  'utrust',
#  'wanchain',
#  'arpa-chain',
#  'poa',
#  'ethernity-chain',
#  'peakdefi',
#  'morpheus-network',
#  'dkargo',
#  'litentry',
#  'dodo',
#  'allianceblock',
#  'deeper-network',
#  'babyswap',
#  'xsgd',
#  'taboo-token',
#  'rsk-smart-bitcoin',
#  'zb-token',
#  'biswap',
#  'gods-unchained',
#  'usdx-kava',
#  'bitshares',
#  'balancer',
#  'haven-protocol',
#  'thunder-token',
#  'strike',
#  'irisnet',
#  'clover',
#  'hoge-finance',
#  'mixmarvel',
#  'lto-network',
#  'cocos-bcx',
#  'impossible-decentralized-incubator-access',
#  'klever',
#  'ampleforth-governance-token',
#  'glitch',
#  'mainframe',
#  'carry',
#  'cyclub',
#  'mxc',
#  'yearn-finance-ii',
#  'atari-token',
#  'biopassport-token',
#  'cvault-finance',
#  'shiden-network',
#  'splintershards',
#  'ankreth',
#  'lgcy-network',
#  'moss-coin',
#  'hunt',
#  'milk-alliance',
#  'safe',
#  'komodo',
#  'barnbridge',
#  'zkswap',
#  'chimpion',
#  'vvs-finance',
#  'tranchess',
#  'whale',
#  'dusk-network',
#  'wrapped-nxm',
#  'ssv-network',
#  'loom-network',
#  'boringdao',
#  'susd',
#  'sentinel',
#  'travala',
#  'newscrypto',
#  'akropolis',
#  'alpha-quark-token',
#  'propy',
#  'streamr',
#  'define',
#  'ramp',
#  'karura',
#  'troy',
#  'ethereum-swarm',
#  'celo-dollar',
#  'aergo',
#  'bluzelle',
#  'fox-token',
#  'marinade',
#  'monacoin',
#  'starterra',
#  'liquity',
#  'aion',
#  'tellor',
#  'quickswap',
#  'parsiq',
#  'apeswap-finance',
#  'bella-protocol',
#  'rarible',
#  'pangolin',
#  'bzx-protocol',
#  'urus',
#  'dia',
#  'newyork-exchange',
#  'beefy-finance',
#  'presearch',
#  'cudos',
#  'district0x',
#  'shyft-network',
#  'aleph-im',
#  'keeperdao',
#  'stasis-euro',
#  'adx-net',
#  'venus-usdc',
#  'freeway-token',
#  'venus-xvs',
#  'sentinel-protocol',
#  'alpaca-finance',
#  'crabada',
#  'firo',
#  'vai',
#  'xdai',
#  'hard-protocol',
#  'oxygen',
#  'lido-dao',
#  'adshares',
#  'assemble-protocol',
#  'refereum',
#  'xenioscoin',
#  'suku',
#  'elitium',
#  'math',
#  'bosagora',
#  'asch',
#  'hyperdao',
#  'ribbon-finance',
#  'mantra-dao',
#  'mithril',
#  'elastos',
#  'tokenpocket',
#  'moviebloc',
#  'dad',
#  'dego-finance',
#  'gas',
#  'revv',
#  'beyond-protocol',
#  'flamingo',
#  'rchain',
#  'groestlcoin',
#  'benqi',
#  'harvest-finance',
#  'sifchain',
#  'paid-network',
#  'torum',
#  'vempire-ddao',
#  'unifty',
#  'doge-dash',
#  'vegaprotocol',
#  'bread',
#  'frontier',
#  'contentos',
#  'tokenlon-network-token',
#  'strong',
#  'rai',
#  'marlin',
#  'energi',
#  'kryll',
#  'tnc-coin',
#  'saito',
#  'metronome',
#  'edgeware',
#  'waltonchain',
#  'hackenai',
#  'chain-guardians',
#  'bytom',
#  'firmachain',
#  'bytecoin-bcn',
#  'pac-protocol',
#  'videocoin',
#  'darma-cash',
#  'selfkey',
#  'digixdao',
#  'bitmart-token',
#  'polkabridge',
#  'position-exchange',
#  'kava-swap',
#  'velo',
#  'steem-dollars',
#  'rainicorn',
#  'sora',
#  'valobit',
#  'redd',
#  'fio-protocol',
#  'qcash',
#  'six',
#  'gny',
#  'hegic',
#  'polkafoundry',
#  'polkadex',
#  'galaxy-heroes-coin',
#  'coinex-token',
#  'openocean',
#  'starship',
#  'kleros',
#  'dock',
#  'multivac',
#  'aeternity',
#  'nimiq',
#  'beam',
#  'adapad',
#  'veruscoin',
#  'new-bitshares',
#  'zimbocash',
#  'dextools',
#  'maro',
#  'maple',
#  'efforce',
#  'gomining-token',
#  'burger-swap',
#  'yield-app',
#  'grid',
#  'btu-protocol',
#  'bepro-network',
#  'bounce-token',
#  'unifi-protocol-dao',
#  'gamezone',
#  'airswap',
#  'apollo-currency',
#  'mimblewimblecoin',
#  'civilization',
#  'mint-club',
#  'revolution-populi',
#  'dora-factory',
#  'amo-coin',
#  'fusion',
#  'latoken',
#  'reflexer-ungovernance-token',
#  'cryptoplanes',
#  'gameswap',
#  'faraland',
#  'cellframe',
#  'stackos',
#  'kylin',
#  'venus-busd',
#  'singularitydao',
#  'vite',
#  'sharetoken',
#  'milc-platform',
#  'blockv',
#  'electric-vehicle-zone',
#  'neutrino-system-base-token',
#  'basic',
#  'gamee',
#  'hot-cross',
#  'o3-swap',
#  'mileverse',
#  'hamster',
#  'paris-saint-germain-fan-token',
#  'powerpool',
#  'covalent',
#  'dexe',
#  'crustnetwork',
#  'clearpool',
#  'veritaseum',
#  'wirex-token',
#  'nuls',
#  'pivx',
#  'auto',
#  'nftx',
#  'stratos',
#  'unfederalreserve',
#  'torn',
#  'aragon-court',
#  'pnetwork',
#  'orion-money',
#  'axel',
#  'v-systems',
#  'the-force-protocol',
#  'blockchain-monster-hunt',
#  'deri-protocol',
#  'dragonchain',
#  'perlin',
#  'epic-cash',
#  'measurable-data-token',
#  'solve',
#  'counterparty',
#  'cargox',
#  'dehub',
#  'hydra',
#  'juggernaut',
#  'ferrum-network',
#  'saffron-finance',
#  'ultiledger',
#  'nftb',
#  'gxchain',
#  'quiztok',
#  'pendle',
#  'k21',
#  'gamecredits',
#  'mogul-productions',
#  'lazio-fan-token',
#  'x-world-games',
#  'chrono-tech',
#  'astroswap',
#  'gifto',
#  'polkamarkets',
#  'polkamon',
#  'quantstamp',
#  'mcdex',
#  'vidt-datalink',
#  'everest',
#  'nexus',
#  'poolz-finance',
#  'router-protocol',
#  'drep-new',
#  'erc20',
#  'belt',
#  'bnbpay',
#  'lotto',
#  'darwinia-network',
#  'dsla-protocol',
#  'raiden-network-token',
#  'bitrue-coin',
#  'gochain',
#  'exeedme',
#  'oxbull-tech',
#  'niftyx-protocol',
#  'numbers-protocol',
#  'wing',
#  'mstable-usd',
#  'visor-finance',
#  'zigcoin',
#  'paraswap',
#  'cortex',
#  'super-zero-protocol',
#  'lightning',
#  'cutcoin',
#  'fc-barcelona-fan-token',
#  'pulsepad',
#  'spiritswap',
#  'bridge-mutual',
#  'only1',
#  'invictus-hyperion-fund',
#  'manchester-city-fan-token',
#  'aurora',
#  'xeno-token',
#  'ahatoken',
#  'dxdao',
#  'wagyuswap',
#  'map-protocol',
#  'populous',
#  'rangers-protocol',
#  'sparkpoint',
#  'defina-finance',
#  'convergence',
#  'oxen',
#  'kccpad',
#  'huobi-pool-token',
#  'bitforex-token',
#  'karma-eos',
#  'scprime',
#  'talken',
#  'vertcoin',
#  'coinloan',
#  'ternoa',
#  'platoncoin',
#  'gamercoin',
#  'growthdefi',
#  'hiblocks',
#  'cumrocket',
#  'ariva',
#  'unisocks',
#  'don-key',
#  'degenerator-meme',
#  'chainx',
#  'likecoin',
#  'waykichain',
#  'jigstack',
#  'hermez-network',
#  '0chain',
#  'bankera',
#  'grin',
#  'elysia',
#  'shopping',
#  'curate',
#  'terra-krw',
#  'cardstack',
#  'smartkey',
#  'yflink',
#  'opacity',
#  'duckdaodime',
#  'lattice-token',
#  'vimworld',
#  'metahash',
#  'rubic',
#  'anrkey-x',
#  'infinity-pad',
#  'vesper',
#  'wall-street-games',
#  'venus-usdt',
#  'thorstarter',
#  '1irstcoin',
#  'cindicator',
#  'the-midas-touch-gold',
#  'bifrost-bnc',
#  'epns',
#  'locus-chain',
#  'medacoin',
#  'dxchain-token',
#  'warena',
#  'validity',
#  'babb',
#  'fc-porto',
#  'ubix-network',
#  'bux-token',
#  'observer',
#  'asta',
#  'revomon',
#  'santiment',
#  'bemil-coin',
#  'umbrella-network',
#  'poseidon-network',
#  'vibe',
#  'digg',
#  'deepbrain-chain',
#  'senso',
#  'bitkan',
#  'te-food',
#  'temco',
#  'get-protocol',
#  'circuits-of-value',
#  'monsta-infinite',
#  'tokenclub',
#  'neblio',
#  'smart-mfg',
#  'reserve',
#  'kryptomon',
#  'btse',
#  'zano',
#  'usdk',
#  'namecoin',
#  'apy-finance',
#  'lossless',
#  'lamden',
#  'binamon',
#  'peony',
#  'nav-coin',
#  'crowns',
#  'taraxa',
#  'fairgame',
#  'aidos-kuneen',
#  'zeroswap',
#  'unilend',
#  'qash',
#  'permission-coin',
#  'life-crypto',
#  'xaya',
#  'hodooi',
#  'smartlands-network',
#  'wabi',
#  'student-coin',
#  'tower-token',
#  'nebulas-token',
#  'quantum-resistant-ledger',
#  'trias-token',
#  'lithium',
#  'stakenet',
#  'sentivate',
#  'misbloc',
#  'fountain',
#  'hypercash',
#  'meta',
#  'obyte',
#  'banano',
#  'bitball-treasure',
#  'suterusu',
#  'sincity-token',
#  'olyseum',
#  'sarcophagus',
#  'maps',
#  'solrise-finance',
#  'eden-network',
#  'library-credits',
#  'swash',
#  'xmon',
#  'electra-protocol',
#  'peercoin',
#  'nash-exchange',
#  'uncx',
#  'doggy',
#  'oneledger',
#  'phoenix-global-new',
#  'dexlab',
#  'switcheo',
#  'tokamak-network',
#  'hapi-one',
#  'epik-protocol',
#  'ethpad',
#  'dfyn-network',
#  'gyen',
#  'particl',
#  'fuse-network',
#  'oraichain-token',
#  'nervenetwork',
#  'amber',
#  'reapchain',
#  'armor',
#  'kalao',
#  'stablexswap',
#  'gate',
#  'foam',
#  'proximax',
#  'morpheus-labs',
#  'gmcoin',
#  'spartan-protocol',
#  'mirrored-invesco-qqq-trust',
#  'nucleus-vision',
#  'callisto-network',
#  'nest-protocol',
#  'pacoca',
#  'tranche-finance',
#  'usdx-lighthouse',
#  'emirex-token',
#  'cream-finance',
#  'safecoin',
#  'beyond-finance',
#  'project-with',
#  'wom-protocol',
#  'ondori',
#  'micropets',
#  'soda-coin',
#  'solfarm',
#  'crpt',
#  'fortknoxster',
#  'finxflo',
#  'gather',
#  'fear-nfts',
#  'massnet',
#  'mirrored-tesla',
#  'galatasaray-fan-token',
#  'hord',
#  'bao-finance',
#  'mirrored-apple',
#  'safemoon-inu',
#  'king-dag',
#  'appcoins',
#  'deepspace',
#  'bigone-token',
#  'rainbow-token',
#  'gocrypto-token',
#  'zeon',
#  'meter-governance',
#  'ichi',
#  'mirrored-microsoft',
#  'binemon',
#  'modefi',
#  'dhedge-dao',
#  'arcblock',
#  'pickle-finance',
#  'venus-reward-token',
#  'phantasma-energy',
#  'ac-milan-fan-token',
#  'sonar',
#  'ring-x-platform',
#  'antimatter',
#  'oax',
#  'launchzone',
#  'dforce',
#  'sonm-bep20',
#  'mysterium',
#  'bondly',
#  'genaro-network',
#  'pawtocol',
#  'dogs-of-elon',
#  'minter-network',
#  'free-coin',
#  'mirrored-ishares-silver-trust',
#  'swingby',
#  'adora-token',
#  'bitball',
#  'metaverse',
#  'robonomics-network',
#  'ignis',
#  'vsxp',
#  'arianee-protocol',
#  'synthetify',
#  'mirrored-amazon',
#  'contracoin',
#  'signum',
#  'fleta',
#  'nafter',
#  'unicly-cryptopunks-collection',
#  'eos-force',
#  'well-token',
#  'cashaa',
#  'stafi',
#  'polyswarm',
#  'cyberfi',
#  'govi',
#  'atletico-de-madrid-fan-token',
#  'conun',
#  'degate',
#  'bsc-station',
#  'iqeon',
#  'matrix-ai-network',
#  'labs-group',
#  'julswap',
#  'cryptocean',
#  'venus-ltc',
#  'factom',
#  'vidya',
#  'project-pai',
#  'polkawar',
#  'agoras-tokens',
#  'bird-money',
#  'dafi-protocol',
#  'probit-token',
#  'mirrored-ishares-gold-trust',
#  'betu',
#  'mirrored-netflix',
#  'rio-defi',
#  'exnetwork-token',
#  'bnktothefuture',
#  'mirrored-proshares-vix-short-term-futures-etf',
#  'konomi-network',
#  'cirus-foundation',
#  ...]

# %%
# get temp_url
mainurl = 'https://coinmarketcap.com/'
mainurl_1 = 'currencies'

rank_list = []
watchlist_list = []
marketcap_list = []

for i in range(len(cryp_list)):#shorten
    temp_cryp = cryp_list[i]
    temp_url = mainurl + mainurl_1 + '/' + temp_cryp
    temp_url
    
    temp_resp = requests.get(temp_url)
    temp_soup = bs.BeautifulSoup(temp_resp.text, 'lxml')
    temp_soup

    for i in temp_soup.findAll('div', class_= 'namePill'):
        if 'Rank #' in i.text:
            print(i.text)
            rank_list.append(i.text)
        if 'watchlists' in i.text:
            watchlist_list.append(i.text)    
    
    # for i in soup.findAll('div', class_ = 'statsValue')[0]:
#         marketcap = i.text
#         marketcap_list.append(marketcap)
    #     marketcap = int(i.text.replace(',','').replace('$', ''))
    #     print(marketcap)
# Out:
# Rank #1
# Rank #2
# Rank #3
# Rank #4
# Rank #5
# Rank #6
# Rank #7
# Rank #8
# Rank #9
# Rank #10
# Rank #11
# Rank #12
# Rank #13
# Rank #14
# Rank #15
# Rank #16
# Rank #17
# Rank #18
# Rank #19
# Rank #20
# Rank #21
# Rank #22
# Rank #23
# Rank #24
# Rank #25
# Rank #26
# Rank #27
# Rank #28
# Rank #29
# Rank #30
# Rank #31
# Rank #32
# Rank #33
# Rank #34
# Rank #35
# Rank #36
# Rank #37
# Rank #38
# Rank #39
# Rank #40
# Rank #41
# Rank #42
# Rank #43
# Rank #44
# Rank #45
# Rank #46
# Rank #47
# Rank #48
# Rank #49
# Rank #50
# Rank #51
# Rank #52
# Rank #53
# Rank #54
# Rank #55
# Rank #56
# Rank #57
# Rank #58
# Rank #59
# Rank #60
# Rank #61
# Rank #62
# Rank #63
# Rank #64
# Rank #65
# Rank #66
# Rank #67
# Rank #68
# Rank #69
# Rank #70
# Rank #71
# Rank #72
# Rank #73
# Rank #74
# Rank #75
# Rank #76
# Rank #77
# Rank #78
# Rank #79
# Rank #80
# Rank #81
# Rank #82
# Rank #83
# Rank #84
# Rank #85
# Rank #86
# Rank #87
# Rank #89
# Rank #89
# Rank #90
# Rank #91
# Rank #92
# Rank #93
# Rank #94
# Rank #95
# Rank #96
# Rank #97
# Rank #98
# Rank #99
# Rank #100
# Rank #101
# Rank #102
# Rank #103
# Rank #104
# Rank #105
# Rank #106
# Rank #107
# Rank #108
# Rank #109
# Rank #111
# Rank #111
# Rank #112
# Rank #113
# Rank #114
# Rank #115
# Rank #116
# Rank #117
# Rank #118
# Rank #119
# Rank #121
# Rank #120
# Rank #122
# Rank #123
# Rank #124
# Rank #125
# Rank #126
# Rank #127
# Rank #128
# Rank #129
# Rank #131
# Rank #129
# Rank #132
# Rank #133
# Rank #134
# Rank #135
# Rank #136
# Rank #137
# Rank #138
# Rank #139
# Rank #140
# Rank #141
# Rank #143
# Rank #142
# Rank #144
# Rank #145
# Rank #146
# Rank #147
# Rank #148
# Rank #151
# Rank #151
# Rank #151
# Rank #152
# Rank #153
# Rank #155
# Rank #155
# Rank #157
# Rank #157
# Rank #158
# Rank #159
# Rank #160
# Rank #161
# Rank #162
# Rank #163
# Rank #164
# Rank #165
# Rank #166
# Rank #167
# Rank #167
# Rank #169
# Rank #170
# Rank #171
# Rank #172
# Rank #173
# Rank #174
# Rank #175
# Rank #176
# Rank #177
# Rank #178
# Rank #180
# Rank #180
# Rank #181
# Rank #183
# Rank #183
# Rank #184
# Rank #185
# Rank #186
# Rank #187
# Rank #190
# Rank #188
# Rank #190
# Rank #191
# Rank #193
# Rank #193
# Rank #194
# Rank #195
# Rank #196
# Rank #197
# Rank #199
# Rank #198
# Rank #200
# Rank #201
# Rank #202
# Rank #203
# Rank #204
# Rank #205
# Rank #206
# Rank #207
# Rank #208
# Rank #209
# Rank #210
# Rank #211
# Rank #212
# Rank #213
# Rank #214
# Rank #215
# Rank #216
# Rank #217
# Rank #218
# Rank #219
# Rank #220
# Rank #222
# Rank #221
# Rank #223
# Rank #225
# Rank #225
# Rank #226
# Rank #227
# Rank #228
# Rank #229
# Rank #230
# Rank #232
# Rank #231
# Rank #233
# Rank #234
# Rank #235
# Rank #236
# Rank #237
# Rank #238
# Rank #239
# Rank #240
# Rank #241
# Rank #242
# Rank #243
# Rank #244
# Rank #245
# Rank #246
# Rank #247
# Rank #248
# Rank #249
# Rank #250
# Rank #251
# Rank #252
# Rank #254
# Rank #253
# Rank #255
# Rank #256
# Rank #257
# Rank #258
# Rank #259
# Rank #260
# Rank #260
# Rank #262
# Rank #263
# Rank #264
# Rank #265
# Rank #266
# Rank #269
# Rank #267
# Rank #268
# Rank #270
# Rank #271
# Rank #273
# Rank #272
# Rank #274
# Rank #276
# Rank #276
# Rank #277
# Rank #277
# Rank #279
# Rank #280
# Rank #281
# Rank #282
# Rank #284
# Rank #283
# Rank #285
# Rank #286
# Rank #287
# Rank #288
# Rank #289
# Rank #290
# Rank #291
# Rank #292
# Rank #293
# Rank #296
# Rank #294
# Rank #294
# Rank #296
# Rank #298
# Rank #296
# Rank #300
# Rank #301
# Rank #302
# Rank #304
# Rank #303
# Rank #305
# Rank #306
# Rank #307
# Rank #308
# Rank #309
# Rank #310
# Rank #312
# Rank #311
# Rank #313
# Rank #314
# Rank #316
# Rank #317
# Rank #318
# Rank #318
# Rank #319
# Rank #320
# Rank #321
# Rank #322
# Rank #323
# Rank #324
# Rank #328
# Rank #325
# Rank #327
# Rank #326
# Rank #329
# Rank #331
# Rank #330
# Rank #332
# Rank #333
# Rank #331
# Rank #334
# Rank #338
# Rank #335
# Rank #339
# Rank #338
# Rank #340
# Rank #341
# Rank #342
# Rank #343
# Rank #345
# Rank #344
# Rank #346
# Rank #350
# Rank #348
# Rank #349
# Rank #352
# Rank #350
# Rank #350
# Rank #355
# Rank #354
# Rank #353
# Rank #356
# Rank #357
# Rank #359
# Rank #358
# Rank #360
# Rank #361
# Rank #362
# Rank #363
# Rank #365
# Rank #366
# Rank #367
# Rank #364
# Rank #368
# Rank #369
# Rank #370
# Rank #372
# Rank #371
# Rank #373
# Rank #374
# Rank #374
# Rank #376
# Rank #377
# Rank #378
# Rank #379
# Rank #380
# Rank #381
# Rank #382
# Rank #383
# Rank #384
# Rank #385
# Rank #387
# Rank #388
# Rank #388
# Rank #389
# Rank #390
# Rank #391
# Rank #393
# Rank #393
# Rank #394
# Rank #398
# Rank #395
# Rank #396
# Rank #397
# Rank #399
# Rank #400
# Rank #402
# Rank #401
# Rank #404
# Rank #404
# Rank #406
# Rank #405
# Rank #407
# Rank #408
# Rank #409
# Rank #412
# Rank #410
# Rank #411
# Rank #413
# Rank #415
# Rank #416
# Rank #417
# Rank #419
# Rank #418
# Rank #419
# Rank #420
# Rank #421
# Rank #423
# Rank #423
# Rank #424
# Rank #425
# Rank #426
# Rank #427
# Rank #428
# Rank #431
# Rank #429
# Rank #430
# Rank #432
# Rank #433
# Rank #435
# Rank #435
# Rank #436
# Rank #440
# Rank #438
# Rank #435
# Rank #439
# Rank #441
# Rank #442
# Rank #444
# Rank #443
# Rank #445
# Rank #447
# Rank #446
# Rank #448
# Rank #450
# Rank #449
# Rank #450
# Rank #453
# Rank #452
# Rank #455
# Rank #454
# Rank #456
# Rank #460
# Rank #459
# Rank #459
# Rank #459
# Rank #461
# Rank #464
# Rank #463
# Rank #465
# Rank #467
# Rank #466
# Rank #464
# Rank #468
# Rank #469
# Rank #470
# Rank #471
# Rank #472
# Rank #473
# Rank #474
# Rank #475
# Rank #476
# Rank #477
# Rank #478
# Rank #479
# Rank #480
# Rank #481
# Rank #484
# Rank #483
# Rank #482
# Rank #489
# Rank #485
# Rank #487
# Rank #490
# Rank #491
# Rank #486
# Rank #491
# Rank #492
# Rank #493
# Rank #494
# Rank #496
# Rank #497
# Rank #495
# Rank #498
# Rank #500
# Rank #500
# Rank #503
# Rank #502
# Rank #502
# Rank #504
# Rank #505
# Rank #506
# Rank #508
# Rank #507
# Rank #509
# Rank #509
# Rank #511
# Rank #512
# Rank #513
# Rank #514
# Rank #516
# Rank #515
# Rank #517
# Rank #518
# Rank #519
# Rank #520
# Rank #521
# Rank #522
# Rank #524
# Rank #527
# Rank #523
# Rank #526
# Rank #533
# Rank #528
# Rank #527
# Rank #530
# Rank #529
# Rank #534
# Rank #534
# Rank #538
# Rank #536
# Rank #537
# Rank #534
# Rank #539
# Rank #539
# Rank #542
# Rank #543
# Rank #537
# Rank #543
# Rank #544
# Rank #546
# Rank #547
# Rank #548
# Rank #554
# Rank #539
# Rank #549
# Rank #559
# Rank #550
# Rank #556
# Rank #553
# Rank #552
# Rank #552
# Rank #555
# Rank #555
# Rank #560
# Rank #561
# Rank #558
# Rank #562
# Rank #565
# Rank #564
# Rank #564
# Rank #565
# Rank #567
# Rank #568
# Rank #569
# Rank #571
# Rank #570
# Rank #572
# Rank #573
# Rank #577
# Rank #575
# Rank #574
# Rank #578
# Rank #576
# Rank #579
# Rank #580
# Rank #581
# Rank #587
# Rank #582
# Rank #586
# Rank #585
# Rank #583
# Rank #588
# Rank #589
# Rank #591
# Rank #592
# Rank #590
# Rank #593
# Rank #594
# Rank #595
# Rank #598
# Rank #598
# Rank #599
# Rank #601
# Rank #595
# Rank #602
# Rank #598
# Rank #603
# Rank #583
# Rank #604
# Rank #607
# Rank #605
# Rank #607
# Rank #609
# Rank #602
# Rank #610
# Rank #611
# Rank #614
# Rank #613
# Rank #616
# Rank #616
# Rank #619
# Rank #612
# Rank #617
# Rank #621
# Rank #618
# Rank #621
# Rank #622
# Rank #624
# Rank #625
# Rank #626
# Rank #617
# Rank #627
# Rank #629
# Rank #627
# Rank #629
# Rank #633
# Rank #632
# Rank #631
# Rank #636
# Rank #634
# Rank #634
# Rank #640
# Rank #638
# Rank #639
# Rank #636
# Rank #641
# Rank #642
# Rank #655
# Rank #643
# Rank #644
# Rank #646
# Rank #645
# Rank #647
# Rank #648
# Rank #648
# Rank #651
# Rank #650
# Rank #652
# Rank #653
# Rank #656
# Rank #658
# Rank #654
# Rank #669
# Rank #656
# Rank #656
# Rank #661
# Rank #664
# Rank #662
# Rank #660
# Rank #663
# Rank #665
# Rank #692
# Rank #667
# Rank #668
# Rank #676
# Rank #666
# Rank #670
# Rank #672
# Rank #672
# Rank #673
# Rank #675
# Rank #677
# Rank #678
# Rank #676
# Rank #680
# Rank #680
# Rank #682
# Rank #682
# Rank #685
# Rank #685
# Rank #683
# Rank #688
# Rank #689
# Rank #688
# Rank #689
# Rank #691
# Rank #691
# Rank #694
# Rank #693
# Rank #698
# Rank #695
# Rank #699
# Rank #698
# Rank #696
# Rank #702
# Rank #706
# Rank #705
# Rank #701
# Rank #703
# Rank #704
# Rank #707
# Rank #715
# Rank #708
# Rank #710
# Rank #712
# Rank #709
# Rank #711
# Rank #715
# Rank #713
# Rank #714
# Rank #719
# Rank #717
# Rank #718
# Rank #721
# Rank #721
# Rank #723
# Rank #722
# Rank #724
# Rank #725
# Rank #728
# Rank #726
# Rank #728
# Rank #730
# Rank #730
# Rank #732
# Rank #735
# Rank #735
# Rank #733
# Rank #734
# Rank #747
# Rank #742
# Rank #737
# Rank #731
# Rank #739
# Rank #740
# Rank #743
# Rank #743
# Rank #741
# Rank #746
# Rank #745
# Rank #747
# Rank #750
# Rank #749
# Rank #755
# Rank #752
# Rank #752
# Rank #753
# Rank #754
# Rank #757
# Rank #756
# Rank #766
# Rank #760
# Rank #761
# Rank #749
# Rank #762
# Rank #762
# Rank #765
# Rank #761
# Rank #773
# Rank #764
# Rank #767
# Rank #769
# Rank #767
# Rank #772
# Rank #768
# Rank #775
# Rank #776
# Rank #780
# Rank #777
# Rank #812
# Rank #777
# Rank #779
# Rank #770
# Rank #781
# Rank #785
# Rank #784
# Rank #782
# Rank #785
# Rank #781
# Rank #786
# Rank #669
# Rank #787
# Rank #789
# Rank #790
# Rank #787
# Rank #792
# Rank #795
# Rank #793
# Rank #796
# Rank #794
# Rank #765
# Rank #801
# Rank #797
# Rank #799
# Rank #798
# Rank #798
# Rank #807
# Rank #801
# Rank #802
# Rank #805
# Rank #806
# Rank #809
# Rank #804
# Rank #804
# Rank #811
# Rank #812
# Rank #813
# Rank #810
# Rank #815
# Rank #816
# Rank #817
# Rank #818
# Rank #820
# Rank #819
# Rank #814
# Rank #821
# Rank #823
# Rank #845
# Rank #837
# Rank #822
# Rank #827
# Rank #827
# Rank #830
# Rank #829
# Rank #825
# Rank #830
# Rank #832
# Rank #836
# Rank #828
# Rank #833
# Rank #834
# Rank #830
# Rank #840
# Rank #835
# Rank #838
# Rank #839
# Rank #843
# Rank #840
# Rank #842
# Rank #844
# Rank #847
# Rank #847
# Rank #846
# Rank #848
# Rank #853
# Rank #852
# Rank #859
# Rank #851
# Rank #854
# Rank #853
# Rank #855
# Rank #856
# Rank #857
# Rank #858
# Rank #861
# Rank #862
# Rank #856
# Rank #862
# Rank #863
# Rank #863
# Rank #867
# Rank #863
# Rank #866
# Rank #869
# Rank #878
# Rank #871
# Rank #871
# Rank #873
# Rank #875
# Rank #872
# Rank #877
# Rank #875
# Rank #880
# Rank #876
# Rank #882
# Rank #882
# Rank #879
# Rank #884
# Rank #882
# Rank #885
# Rank #891
# Rank #887
# Rank #888
# Rank #893
# Rank #892
# Rank #892
# Rank #894
# Rank #885
# Rank #894
# Rank #897
# Rank #895
# Rank #893
# Rank #900
# Rank #891
# Rank #903
# Rank #900
# Rank #902
# Rank #899
# Rank #905
# Rank #906
# Rank #907
# Rank #908
# Rank #909
# Rank #913
# Rank #910
# Rank #920
# Rank #916
# Rank #914
# Rank #915
# Rank #918
# Rank #926
# Rank #918
# Rank #931
# Rank #919
# Rank #912
# Rank #923
# Rank #923
# Rank #916
# Rank #910
# Rank #925
# Rank #927
# Rank #928
# Rank #931
# Rank #933
# Rank #932
# Rank #929
# Rank #934
# Rank #931
# Rank #934
# Rank #936
# Rank #935
# Rank #938
# Rank #941
# Rank #942
# Rank #939
# Rank #944
# Rank #940
# Rank #943
# Rank #946
# Rank #950
# Rank #966
# Rank #949
# Rank #946
# Rank #947
# Rank #945
# Rank #951
# Rank #952
# Rank #953
# Rank #1106
# Rank #955
# Rank #957
# Rank #955
# Rank #957
# Rank #957
# Rank #960
# Rank #963
# Rank #964
# Rank #962
# Rank #967
# Rank #968
# Rank #958
# Rank #971
# Rank #971
# Rank #969
# Rank #968
# Rank #969
# Rank #972
# Rank #974
# Rank #972
# Rank #974
# Rank #980
# Rank #976
# Rank #977
# Rank #976
# Rank #979
# Rank #987
# Rank #982
# Rank #980
# Rank #983
# Rank #989
# Rank #986
# Rank #989
# Rank #988
# Rank #990
# Rank #996
# Rank #992
# Rank #996
# Rank #994
# Rank #998
# Rank #992
# Rank #985
# Rank #997
# Rank #999
# Rank #1000
# Rank #1001
# Rank #1003
# Rank #978
# Rank #1004
# Rank #1007
# Rank #1006
# Rank #1007
# Rank #1009
# Rank #1011
# Rank #1012
# Rank #1013
# Rank #1009
# Rank #1013
# Rank #1015
# Rank #1018
# Rank #1026
# Rank #1016
# Rank #1017
# Rank #1019
# Rank #1020
# Rank #1002
# Rank #1023
# Rank #1022
# Rank #1019
# Rank #1025
# Rank #1021
# Rank #1024
# Rank #1028
# Rank #1029
# Rank #1030
# Rank #1026
# Rank #1032
# Rank #1031
# Rank #1034
# Rank #1035
# Rank #1035
# Rank #1036
# Rank #1037
# Rank #1038
# Rank #1040
# Rank #1046
# Rank #1041
# Rank #1041
# Rank #1042
# Rank #1044
# Rank #1045
# Rank #1046
# Rank #1052
# Rank #1049
# Rank #1047
# Rank #1050
# Rank #1049
# Rank #1050
# Rank #1053
# Rank #1055
# Rank #1055
# Rank #1056
# Rank #1057
# Rank #1063
# Rank #1060
# Rank #1058
# Rank #1079
# Rank #1061
# Rank #1062
# Rank #1065
# Rank #1069
# Rank #1067
# Rank #1067
# Rank #1060
# Rank #1066
# Rank #1069
# Rank #1205
# Rank #1072
# Rank #1072
# Rank #1074
# Rank #1073
# Rank #1075
# Rank #1071
# Rank #1078
# Rank #1077
# Rank #1081
# Rank #1081
# Rank #1085
# Rank #1080
# Rank #1084
# Rank #1084
# Rank #1086
# Rank #1078
# Rank #1087
# Rank #1103
# Rank #1090
# Rank #1090
# Rank #1091
# Rank #1088
# Rank #1094
# Rank #1092
# Rank #1098
# Rank #1095
# Rank #1100
# Rank #1096
# Rank #1098
# Rank #1101
# Rank #1104
# Rank #1104
# Rank #1109
# Rank #1106
# Rank #1109
# Rank #1110
# Rank #1107
# Rank #1108
# Rank #1121
# Rank #1117
# Rank #1102
# Rank #1112
# Rank #1115
# Rank #1114
# Rank #1119
# Rank #1112
# Rank #1119
# Rank #1119
# Rank #1126
# Rank #1121
# Rank #1115
# Rank #1124
# Rank #1122
# Rank #1128
# Rank #1125
# Rank #1127
# Rank #1128
# Rank #1129
# Rank #1130
# Rank #1135
# Rank #1130
# Rank #1133
# Rank #1137
# Rank #1134
# Rank #1135
# Rank #1139
# Rank #1140
# Rank #1134
# Rank #1141
# Rank #1144
# Rank #1142
# Rank #1145
# Rank #1147
# Rank #1147
# Rank #1170
# Rank #1151
# Rank #1149
# Rank #1150
# Rank #1151
# Rank #1175
# Rank #1156
# Rank #1154
# Rank #1143
# Rank #1156
# Rank #1157
# Rank #1158
# Rank #1153
# Rank #1160
# Rank #1161
# Rank #1146
# Rank #1162
# Rank #1159
# Rank #1164
# Rank #1165
# Rank #1163
# Rank #1167
# Rank #1166
# Rank #1171
# Rank #1168
# Rank #1174
# Rank #1173
# Rank #1174
# Rank #1167
# Rank #1176
# Rank #1177
# Rank #1181
# Rank #1181
# Rank #1178
# Rank #1182
# Rank #1182
# Rank #1184
# Rank #1183
# Rank #1186
# Rank #1193
# Rank #1188
# Rank #1187
# Rank #1190
# Rank #1190
# Rank #1192
# Rank #1193
# Rank #1194
# Rank #1201
# Rank #1199
# Rank #1200
# Rank #1197
# Rank #1179
# Rank #1198
# Rank #1200
# Rank #1197
# Rank #1205
# Rank #1205
# Rank #1207
# Rank #1202
# Rank #1207
# Rank #1093
# Rank #1209
# Rank #1224
# Rank #1210
# Rank #1211
# Rank #1206
# Rank #1214
# Rank #1212
# Rank #1214
# Rank #1217
# Rank #1218
# Rank #1217
# Rank #1226
# Rank #1219
# Rank #1221
# Rank #1220
# Rank #1225
# Rank #1224
# Rank #1224
# Rank #1243
# Rank #1228
# Rank #1221
# Rank #1227
# Rank #1232
# Rank #1230
# Rank #1234
# Rank #1238
# Rank #1236
# Rank #1233
# Rank #1230
# Rank #1235
# Rank #1237
# Rank #1239
# Rank #1234
# Rank #1240
# Rank #1240
# Rank #1244
# Rank #1244
# Rank #5460
# Rank #1251
# Rank #1249
# Rank #1251
# Rank #1252
# Rank #1248
# Rank #1250
# Rank #1255
# Rank #1256
# Rank #1256
# Rank #1257
# Rank #1260
# Rank #1260
# Rank #1262
# Rank #1259
# Rank #1277
# Rank #1261
# Rank #1263
# Rank #1268
# Rank #1267
# Rank #1266
# Rank #1268
# Rank #1266
# Rank #1268
# Rank #1272
# Rank #1269
# Rank #1274
# Rank #1271
# Rank #1274
# Rank #1276
# Rank #1278
# Rank #1281
# Rank #1280
# Rank #1279
# Rank #1283
# Rank #1286
# Rank #1286
# Rank #1285
# Rank #1287
# Rank #1266
# Rank #1297
# Rank #1287
# Rank #1290
# Rank #1297
# Rank #1290
# Rank #1225
# Rank #1292
# Rank #1295
# Rank #1295
# Rank #1299
# Rank #1284
# Rank #1300
# Rank #1298
# Rank #1301
# Rank #1302
# Rank #1293
# Rank #1302
# Rank #1304
# Rank #1242
# Rank #1304
# Rank #1306
# Rank #1307
# Rank #1308
# Rank #1310
# Rank #1312
# Rank #1321
# Rank #1309
# Rank #1310
# Rank #1314
# Rank #1315
# Rank #1320
# Rank #1317
# Rank #1319
# Rank #1316
# Rank #1317
# Rank #1323
# Rank #1320
# Rank #1325
# Rank #1326
# Rank #1327
# Rank #1323
# Rank #1328
# Rank #1330
# Rank #1325
# Rank #1331
# Rank #1254
# Rank #1329
# Rank #1334
# Rank #1332
# Rank #1334
# Rank #1339
# Rank #1346
# Rank #1335
# Rank #1336
# Rank #1345
# Rank #1341
# Rank #1341
# Rank #1339
# Rank #1337
# Rank #1343
# Rank #1336
# Rank #1346
# Rank #1349
# Rank #1348
# Rank #1349
# Rank #1338
# Rank #1352
# Rank #1354
# Rank #1351
# Rank #1354
# Rank #1358
# Rank #1356
# Rank #1360
# Rank #1357
# Rank #1359
# Rank #1361
# Rank #1363
# Rank #1361
# Rank #1369
# Rank #1365
# Rank #1362
# Rank #1366
# Rank #1369
# Rank #1368
# Rank #1371
# Rank #1373
# Rank #1367
# Rank #1374
# Rank #1377
# Rank #1374
# Rank #1378
# Rank #1375
# Rank #1381
# Rank #1380
# Rank #1379
# Rank #1392
# Rank #1382
# Rank #1384
# Rank #1383
# Rank #1370
# Rank #1372
# Rank #1433
# Rank #1386
# Rank #1388

# %%
df = pd.DataFrame([cryp_list,rank_list, watchlist_list], columns = ['cryp_list', 'rank_list', 'watchlist_list'])
df['rank_list'] = df['rank_list'].apply(lambda x: int(x.split('Rank #')[-1]))
df['watchlist_list'] = df['watchlist_list'].apply(lambda x: int(x.split('On ')[-1].split(' watchlists')[0].replace(',', '')))
df.sort_values(by=['watchlist_list'], inplace=True,ascending=False)
df

# %%
rank_list
# Out:
# ['Rank #1',
#  'Rank #2',
#  'Rank #3',
#  'Rank #4',
#  'Rank #5',
#  'Rank #6',
#  'Rank #7',
#  'Rank #8',
#  'Rank #9',
#  'Rank #10',
#  'Rank #11',
#  'Rank #12',
#  'Rank #13',
#  'Rank #14',
#  'Rank #15',
#  'Rank #16',
#  'Rank #17',
#  'Rank #18',
#  'Rank #19',
#  'Rank #20',
#  'Rank #21',
#  'Rank #22',
#  'Rank #23',
#  'Rank #24',
#  'Rank #25',
#  'Rank #26',
#  'Rank #27',
#  'Rank #28',
#  'Rank #29',
#  'Rank #30',
#  'Rank #31',
#  'Rank #32',
#  'Rank #33',
#  'Rank #34',
#  'Rank #35',
#  'Rank #36',
#  'Rank #37',
#  'Rank #38',
#  'Rank #39',
#  'Rank #40',
#  'Rank #41',
#  'Rank #42',
#  'Rank #43',
#  'Rank #44',
#  'Rank #45',
#  'Rank #47',
#  'Rank #47',
#  'Rank #48',
#  'Rank #49',
#  'Rank #50']

# %%
watchlist_list
# Out:
# ['On 2,938,309 watchlists',
#  'On 2,347,004 watchlists',
#  'On 1,295,187 watchlists',
#  'On 539,917 watchlists',
#  'On 1,031,068 watchlists',
#  'On 1,876,751 watchlists',
#  'On 1,462,416 watchlists',
#  'On 125,675 watchlists',
#  'On 1,082,459 watchlists',
#  'On 1,399,681 watchlists',
#  'On 506,937 watchlists',
#  'On 1,935,011 watchlists',
#  'On 412,491 watchlists',
#  'On 530,766 watchlists',
#  'On 692,684 watchlists',
#  'On 837,948 watchlists',
#  'On 46,541 watchlists',
#  'On 471,668 watchlists',
#  'On 116,215 watchlists',
#  'On 813,596 watchlists',
#  'On 431,518 watchlists',
#  'On 329,508 watchlists',
#  'On 369,738 watchlists',
#  'On 620,273 watchlists',
#  'On 734,221 watchlists',
#  'On 903,983 watchlists',
#  'On 285,647 watchlists',
#  'On 406,246 watchlists',
#  'On 22,262 watchlists',
#  'On 232,688 watchlists',
#  'On 182,183 watchlists',
#  'On 684,711 watchlists',
#  'On 376,844 watchlists',
#  'On 92,236 watchlists',
#  'On 288,759 watchlists',
#  'On 323,995 watchlists',
#  'On 420,034 watchlists',
#  'On 19,191 watchlists',
#  'On 859,503 watchlists',
#  'On 433,419 watchlists',
#  'On 150,253 watchlists',
#  'On 338,075 watchlists',
#  'On 258,609 watchlists',
#  'On 277,110 watchlists',
#  'On 274,552 watchlists',
#  'On 208,295 watchlists',
#  'On 61,487 watchlists',
#  'On 377,588 watchlists',
#  'On 117,868 watchlists',
#  'On 312,721 watchlists']
